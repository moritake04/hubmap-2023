# %% [markdown]
# # Import

# %%
import mmdet
import mmcv
import mmengine
from mmengine import Config
from mmengine.runner import set_random_seed
#from mmdet.datasets import build_dataset
#from mmdet.models import build_detector
from mmengine.runner import Runner
from mmdet.apis import init_detector, inference_detector
from mmengine.visualization import Visualizer

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import json

import warnings
warnings.filterwarnings('ignore') #Ignore "future" warnings and Data-Frame-Slicing warnings.

from sklearn.model_selection import KFold, StratifiedKFold
from pytorch_lightning import seed_everything

# %% [markdown]
# # Config

# %%
class CFG:
    class general:
        #project_name = "HuBMAP2023"
        input_path = "../data/input"
        output_path = "../data/output"
        save_name = "convnext_all_pseudo09"
        seed = 0
        cv = True
        #wandb_desabled = True
        n_splits = 5
        fold = [0] # list (0-idx start) or null. Set one element list, hold-out mode.

# %% [markdown]
# # Main

# %% [markdown]
# ### Read data

# %%
tile_meta = pd.read_csv(f"{CFG.general.input_path}/tile_meta.csv")
polygons = pd.read_json(f"{CFG.general.input_path}/polygons.jsonl", lines=True)
train = pd.merge(polygons, tile_meta, on="id", how="left")
print(len(train))
# Out:
# 1633

# %%
with open(f"{CFG.general.input_path}/coco_annotations_all.json") as f:
    coco_json = json.load(f)

# %%
coco_info = pd.DataFrame(coco_json["info"])
coco_licenses = pd.DataFrame(coco_json["licenses"])
coco_categories = pd.DataFrame(coco_json["categories"])
coco_images = pd.DataFrame(coco_json["images"])
coco_annotations = pd.DataFrame(coco_json["annotations"])

# %%
with open(f"{CFG.general.input_path}/coco_annotations_pseudo_c09_train_all.json") as f:
    coco_pseudo_json = json.load(f)

# %%
coco_info_pseudo = pd.DataFrame(coco_pseudo_json["info"])
coco_licenses_pseudo = pd.DataFrame(coco_pseudo_json["licenses"])
coco_categories_pseudo = pd.DataFrame(coco_pseudo_json["categories"])
coco_images_pseudo = pd.DataFrame(coco_pseudo_json["images"])
coco_annotations_pseudo = pd.DataFrame(coco_pseudo_json["annotations"])

# %%
# pseudo label データ使うかどうか
coco_images = pd.concat([coco_images, coco_images_pseudo]).reset_index(drop=True)
coco_annotations = pd.concat([coco_annotations, coco_annotations_pseudo]).reset_index(drop=True)

# pseudo label only
#coco_images_train = coco_images_pseudo
#coco_annotations_train = coco_annotations_pseudo

# bloodだけにするかどうか
coco_annotations = coco_annotations[coco_annotations["category_id"]==2].reset_index(drop=True)

# unsureを除くかどうか
#coco_annotations = coco_annotations[coco_annotations["category_id"]!=3].reset_index(drop=True)

# glomerulusを除くかどうか
#coco_annotations = coco_annotations[coco_annotations["category_id"]!=1].reset_index(drop=True)      

# unsureをbloodにするかどうか
#coco_annotations.loc[coco_annotations["category_id"]==3, "category_id"] = 2

coco_annotations["id"] = coco_annotations.index + 1

coco_json["categories"] = [coco_categories.iloc[1].to_dict()]
#coco_json["categories"] = coco_categories.iloc[:2].to_dict(orient="records")

coco_json["images"] = coco_images.to_dict(orient="records")
coco_json["annotations"] = coco_annotations.to_dict(orient="records")

output_file_path = f"{CFG.general.input_path}/coco_annotations_train_all.json"
with open(output_file_path, "w", encoding="utf-8") as output_file:
    json.dump(coco_json, output_file, ensure_ascii=True, indent=4)

print(f"annos: {len(coco_annotations)}, images: {len(coco_images)}")
# Out:
# annos: 47860, images: 7033

# %%
backbone = "convnext"
if backbone == "convnext":
    cfg = Config.fromfile("../mmdetection/configs/convnext/cascade-mask-rcnn_convnext-t-p4-w7_fpn_4conv1fc-giou_amp-ms-crop-3x_coco.py")
    #cfg.work_dir = ""
    #Runner.from_cfg(cfg)
    
    # cfg dataset
    cfg.metainfo = {
        #"classes": ("glomerulus", "blood_vessel", )
        "classes": ("blood_vessel", )
    }
    cfg.train_pipeline = [
            dict(type="LoadImageFromFile", backend_args=None),
            dict(type="LoadAnnotations", with_bbox=True, with_mask=True, poly2mask=True),
            dict(
                type="RandomChoiceResize",
                scales=[(640, 640), (768, 768), (896, 896), (1024, 1024), (1152, 1152), (1280, 1280), (1408, 1408), (1536, 1536)],
                keep_ratio=True),
            dict(
                #type="RandomFlip", direction=["horizontal", "vertical"], prob=[0.5, 0.5],
                type="RandomFlip",prob=0.0
                ),
            dict(type="PackDetInputs")
        ]
    cfg.train_dataloader.dataset.pipeline = cfg.train_pipeline
    cfg.test_pipeline = [
            dict(type="LoadImageFromFile", backend_args=None),
            dict(type="Resize", scale=(1024, 1024), keep_ratio=True),
            dict(type="LoadAnnotations", with_bbox=True, with_mask=True),
            dict(
                type="PackDetInputs",
                meta_keys=("img_id", "img_path", "ori_shape", "img_shape", "scale_factor"))
        ]
    cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
    cfg.data_root = f"{CFG.general.input_path}"
    cfg.train_dataloader.dataset.ann_file = f"coco_annotations_train_all.json"
    cfg.train_dataloader.dataset.data_root = cfg.data_root
    cfg.train_dataloader.dataset.data_prefix.img = "train"
    cfg.train_dataloader.dataset.metainfo = cfg.metainfo
    cfg.val_dataloader = None
    cfg.val_evaluator = None
    cfg.val_cfg = None
    cfg.test_dataloader = None
    cfg.test_evaluator = None 
    cfg.test_cfg = None

    # classes
    cfg.model.roi_head.bbox_head[0].num_classes = 1
    cfg.model.roi_head.bbox_head[1].num_classes = 1
    cfg.model.roi_head.bbox_head[2].num_classes = 1
    cfg.model.roi_head.mask_head.num_classes = 1

    # pretrained weight
    #cfg.load_from = "../data/pretrained_weight/cascade_mask_rcnn_convnext-t_p4_w7_fpn_giou_4conv1f_fp16_ms-crop_3x_coco_20220509_204200-8f07c40b.pth"
    cfg.load_from = "/notebooks/data/output/base_all/exp130_convnext_all/epoch_1.pth"

    # Set up working dir to save files and logs
    cfg.work_dir = f"{CFG.general.output_path}/{CFG.general.save_name}"

    # training configs, learning rate, optimizer
    max_iter = 10000
    cfg.train_cfg = dict(type="IterBasedTrainLoop", max_iters=max_iter, val_interval=500)
    cfg.train_dataloader.sampler = dict(type="InfiniteSampler", shuffle=True)
    cfg.log_processor = dict(by_epoch=False)
    cfg.optim_wrapper.type = "AmpOptimWrapper"
    #cfg.optim_wrapper.optimizer = dict(type="SGD", lr=0.01, momentum=0.9, weight_decay=1e-05)
    #cfg.optim_wrapper.optimizer = dict(type="AdamW", lr=0.0000002, betas=(0.9, 0.999,), weight_decay=0.05)
    cfg.param_scheduler = [
            dict(
                type="LinearLR", start_factor=1.0e-3, by_epoch=False, begin=0, end=int(max_iter*0.1)),
            dict(
                type="CosineAnnealingLR",
                T_max=max_iter-int(max_iter*0.1),
                by_epoch=False,
                begin=int(max_iter*0.1),
                end=max_iter)
        ]

    # logger
    cfg.default_hooks.checkpoint.interval = 0
    cfg.default_hooks.logger.interval = 100

    # Set seed thus the results are more reproducible
    set_random_seed(CFG.general.seed, deterministic=False)
    
elif backbone == "resnet":
    #cfg = Config.fromfile("../mmdetection/configs/cascade_rcnn/cascade-mask-rcnn_r50_fpn_ms-3x_coco.py")
    cfg = Config.fromfile("../mmdetection/configs/cascade_rcnn/cascade-mask-rcnn_x101-64x4d_fpn_ms-3x_coco.py")
    
    # cfg dataset
    cfg.metainfo = {
        "classes": ("blood_vessel", )
    }
    cfg.train_pipeline = [
            dict(type="LoadImageFromFile", backend_args=None),
            dict(type="LoadAnnotations", with_bbox=True, with_mask=True, poly2mask=True),
            dict(
                type="RandomChoiceResize",
                scales=[(640, 640), (768, 768), (896, 896), (1024, 1024), (1152, 1152), (1280, 1280), (1408, 1408), (1536, 1536)],
                keep_ratio=True),
            dict(
                type="RandomFlip",
            prob=0.0),
            dict(type="PackDetInputs")
        ]
    cfg.train_dataloader.dataset.dataset.pipeline = cfg.train_pipeline
    cfg.test_pipeline = [
            dict(type="LoadImageFromFile", backend_args=None),
            dict(type="Resize", scale=(1024, 1024), keep_ratio=True),
            dict(type="LoadAnnotations", with_bbox=True, with_mask=True),
            dict(
                type="PackDetInputs",
                meta_keys=("img_id", "img_path", "ori_shape", "img_shape", "scale_factor"))
        ]
    cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
    cfg.data_root = f"{CFG.general.input_path}"
    cfg.train_dataloader.dataset.dataset.ann_file = f"coco_annotations_train_all.json"
    cfg.train_dataloader.dataset.dataset.data_root = cfg.data_root
    cfg.train_dataloader.dataset.dataset.data_prefix.img = "train"
    cfg.train_dataloader.dataset.dataset.metainfo = cfg.metainfo
    cfg.val_dataloader = None
    cfg.val_evaluator = None
    cfg.val_cfg = None
    cfg.test_dataloader = None
    cfg.test_evaluator = None 
    cfg.test_cfg = None

    # classes
    cfg.model.roi_head.bbox_head[0].num_classes = 1
    cfg.model.roi_head.bbox_head[1].num_classes = 1
    cfg.model.roi_head.bbox_head[2].num_classes = 1
    cfg.model.roi_head.mask_head.num_classes = 1

    # pretrained weight
    #cfg.load_from = "/notebooks/data/output/base_all/exp132_resnet_all/epoch_1.pth"
    cfg.load_from = "/notebooks/data/output/base_all/exp131_resnext_all/epoch_1.pth"

    # Set up working dir to save files and logs
    cfg.work_dir = f"{CFG.general.output_path}/{CFG.general.save_name}"

    # training configs, learning rate, optimizer
    max_iter = 10000
    cfg.train_cfg = dict(type="IterBasedTrainLoop", max_iters=max_iter, val_interval=500)
    cfg.train_dataloader.sampler = dict(type="InfiniteSampler", shuffle=True)
    cfg.log_processor = dict(by_epoch=False)
    cfg.optim_wrapper.type = "AmpOptimWrapper"
    cfg.optim_wrapper.optimizer.type = "SGD"
    cfg.optim_wrapper.optimizer.lr = 1.0e-2
    cfg.optim_wrapper.optimizer.weight_decay = 1.0e-5
    cfg.param_scheduler = [
            dict(
                type="LinearLR", start_factor=1.0e-3, by_epoch=False, begin=0, end=int(max_iter*0.1)),
            dict(
                type="CosineAnnealingLR",
                T_max=max_iter-int(max_iter*0.1),
                by_epoch=False,
                begin=int(max_iter*0.1),
                end=max_iter)
        ]

    # logger
    cfg.default_hooks.checkpoint.interval = 0
    cfg.default_hooks.logger.interval = 100

    # Set seed thus the results are more reproducible
    set_random_seed(CFG.general.seed, deterministic=False)

elif backbone == "mask2former":
    cfg = Config.fromfile("../mmdetection/configs/mask2former/mask2former_swin-t-p4-w7-224_8xb2-lsj-50e_coco.py")
    #cfg.work_dir = "../../"
    #Runner.from_cfg(cfg)
    
    # cfg dataset
    cfg.metainfo = {
        "classes": ("blood_vessel", )
    }
    cfg.train_pipeline[2] = dict(type="RandomFlip", prob=0.0)
    cfg.train_dataloader.dataset.pipeline = cfg.train_pipeline
    cfg.test_pipeline[1] = dict(type="Resize", scale=(1024, 1024), keep_ratio=True)
    cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
    cfg.data_root = f"{CFG.general.input_path}"
    cfg.train_dataloader.dataset.ann_file = f"coco_annotations_train_fold{fold_n}.json"
    cfg.train_dataloader.dataset.data_root = cfg.data_root
    cfg.train_dataloader.dataset.data_prefix.img = "train"
    cfg.train_dataloader.dataset.metainfo = cfg.metainfo
    cfg.val_dataloader.dataset.ann_file = f"coco_annotations_valid_fold{fold_n}.json"
    cfg.val_dataloader.dataset.data_root = cfg.data_root
    cfg.val_dataloader.dataset.data_prefix.img = "train"
    cfg.val_dataloader.dataset.metainfo = cfg.metainfo
    cfg.test_dataloader = cfg.val_dataloader
    cfg.val_evaluator.ann_file = f"{CFG.general.input_path}/coco_annotations_valid_fold{fold_n}.json"
    cfg.val_evaluator.metric = "segm"
    cfg.test_evaluator = cfg.val_evaluator

    # classes
    cfg.num_things_classes = 1
    cfg.num_classes = 1
    cfg.model.panoptic_head.num_things_classes = cfg.num_things_classes
    cfg.model.panoptic_head.num_stuff_classes = cfg.num_stuff_classes
    cfg.model.panoptic_fusion_head.num_things_classes = cfg.num_things_classes
    cfg.model.panoptic_fusion_head.num_stuff_classes = cfg.num_stuff_classes
    cfg.model.panoptic_head.loss_cls["class_weight"] = [1.0] * cfg.num_classes + [0.1]

    # pretrained weight
    cfg.load_from = "../data/pretrained_weight/mask2former_swin-t-p4-w7-224_8xb2-lsj-50e_coco_20220508_091649-01b0f990.pth"

    # Set up working dir to save files and logs
    cfg.work_dir = f"{CFG.general.output_path}/{CFG.general.save_name}"

    # training configs, learning rate, optimizer
    max_iter = 10000
    cfg.train_cfg = dict(type="IterBasedTrainLoop", max_iters=max_iter, val_interval=500)
    cfg.train_dataloader.sampler = dict(type="InfiniteSampler", shuffle=True)
    cfg.log_processor = dict(by_epoch=False)
    cfg.optim_wrapper.type = "AmpOptimWrapper"
    #cfg.optim_wrapper.optimizer = dict(type="SGD", lr=0.01, momentum=0.9, weight_decay=1e-05)
    cfg.param_scheduler = [
            dict(
                type="LinearLR", start_factor=1.0e-3, by_epoch=False, begin=0, end=int(max_iter*0.1)),
            dict(
                type="CosineAnnealingLR",
                T_max=max_iter-int(max_iter*0.1),
                by_epoch=False,
                begin=int(max_iter*0.1),
                end=max_iter)
        ]

    # logger
    cfg.default_hooks.checkpoint.interval = 0
    cfg.default_hooks.logger.interval = 100

    # Set seed thus the results are more reproducible
    set_random_seed(CFG.general.seed, deterministic=False)

# %%
runner = Runner.from_cfg(cfg)
# Out:
# 07/25 05:16:47 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 (main, Dec  7 2022, 01:11:51) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 209652396
#     GPU 0: NVIDIA RTX A6000
#     CUDA_HOME: /usr/local/cuda-11.6
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.12.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.13.1+cu116
#     OpenCV: 4.6.0
#     MMEngine: 0.8.2
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 209652396
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 07/25 05:16:48 - mmengine - INFO - Config:
# model = dict(
#     type='CascadeRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         bgr_to_rgb=True,
#         pad_mask=True,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='mmpretrain.ConvNeXt',
#         arch='tiny',
#         out_indices=[
#             0,
#             1,
#             2,
#             3,
#         ],
#         drop_path_rate=0.4,
#         layer_scale_init_value=1.0,
#         gap_before_final_norm=False,
#         init_cfg=dict(
#             type='Pretrained',
#             checkpoint=
#             'https://download.openmmlab.com/mmclassification/v0/convnext/downstream/convnext-tiny_3rdparty_32xb128-noema_in1k_20220301-795e9634.pth',
#             prefix='backbone.')),
#     neck=dict(
#         type='FPN',
#         in_channels=[
#             96,
#             192,
#             384,
#             768,
#         ],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[
#                 8,
#             ],
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(
#             type='SmoothL1Loss', beta=0.1111111111111111, loss_weight=1.0)),
#     roi_head=dict(
#         type='CascadeRoIHead',
#         num_stages=3,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ]),
#         bbox_head=[
#             dict(
#                 type='ConvFCBBoxHead',
#                 num_shared_convs=4,
#                 num_shared_fcs=1,
#                 in_channels=256,
#                 conv_out_channels=256,
#                 fc_out_channels=1024,
#                 roi_feat_size=7,
#                 num_classes=1,
#                 bbox_coder=dict(
#                     type='DeltaXYWHBBoxCoder',
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ]),
#                 reg_class_agnostic=False,
#                 reg_decoded_bbox=True,
#                 norm_cfg=dict(type='SyncBN', requires_grad=True),
#                 loss_cls=dict(
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False,
#                     loss_weight=1.0),
#                 loss_bbox=dict(type='GIoULoss', loss_weight=10.0)),
#             dict(
#                 type='ConvFCBBoxHead',
#                 num_shared_convs=4,
#                 num_shared_fcs=1,
#                 in_channels=256,
#                 conv_out_channels=256,
#                 fc_out_channels=1024,
#                 roi_feat_size=7,
#                 num_classes=1,
#                 bbox_coder=dict(
#                     type='DeltaXYWHBBoxCoder',
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ]),
#                 reg_class_agnostic=False,
#                 reg_decoded_bbox=True,
#                 norm_cfg=dict(type='SyncBN', requires_grad=True),
#                 loss_cls=dict(
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False,
#                     loss_weight=1.0),
#                 loss_bbox=dict(type='GIoULoss', loss_weight=10.0)),
#             dict(
#                 type='ConvFCBBoxHead',
#                 num_shared_convs=4,
#                 num_shared_fcs=1,
#                 in_channels=256,
#                 conv_out_channels=256,
#                 fc_out_channels=1024,
#                 roi_feat_size=7,
#                 num_classes=1,
#                 bbox_coder=dict(
#                     type='DeltaXYWHBBoxCoder',
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ]),
#                 reg_class_agnostic=False,
#                 reg_decoded_bbox=True,
#                 norm_cfg=dict(type='SyncBN', requires_grad=True),
#                 loss_cls=dict(
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False,
#                     loss_weight=1.0),
#                 loss_bbox=dict(type='GIoULoss', loss_weight=10.0)),
#         ],
#         mask_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=14, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ]),
#         mask_head=dict(
#             type='FCNMaskHead',
#             num_convs=4,
#             in_channels=256,
#             conv_out_channels=256,
#             num_classes=1,
#             loss_mask=dict(
#                 type='CrossEntropyLoss', use_mask=True, loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=0,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=2000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     type='MaxIoUAssigner',
#                     pos_iou_thr=0.5,
#                     neg_iou_thr=0.5,
#                     min_pos_iou=0.5,
#                     match_low_quality=False,
#                     ignore_iof_thr=-1),
#                 sampler=dict(
#                     type='RandomSampler',
#                     num=512,
#                     pos_fraction=0.25,
#                     neg_pos_ub=-1,
#                     add_gt_as_proposals=True),
#                 mask_size=28,
#                 pos_weight=-1,
#                 debug=False),
#             dict(
#                 assigner=dict(
#                     type='MaxIoUAssigner',
#                     pos_iou_thr=0.6,
#                     neg_iou_thr=0.6,
#                     min_pos_iou=0.6,
#                     match_low_quality=False,
#                     ignore_iof_thr=-1),
#                 sampler=dict(
#                     type='RandomSampler',
#                     num=512,
#                     pos_fraction=0.25,
#                     neg_pos_ub=-1,
#                     add_gt_as_proposals=True),
#                 mask_size=28,
#                 pos_weight=-1,
#                 debug=False),
#             dict(
#                 assigner=dict(
#                     type='MaxIoUAssigner',
#                     pos_iou_thr=0.7,
#                     neg_iou_thr=0.7,
#                     min_pos_iou=0.7,
#                     match_low_quality=False,
#                     ignore_iof_thr=-1),
#                 sampler=dict(
#                     type='RandomSampler',
#                     num=512,
#                     pos_fraction=0.25,
#                     neg_pos_ub=-1,
#                     add_gt_as_proposals=True),
#                 mask_size=28,
#                 pos_weight=-1,
#                 debug=False),
#         ]),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100,
#             mask_thr_binary=0.5)))
# dataset_type = 'CocoDataset'
# data_root = '../data/input'
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='LoadAnnotations', with_bbox=True, with_mask=True,
#         poly2mask=True),
#     dict(
#         type='RandomChoiceResize',
#         scales=[
#             (
#                 640,
#                 640,
#             ),
#             (
#                 768,
#                 768,
#             ),
#             (
#                 896,
#                 896,
#             ),
#             (
#                 1024,
#                 1024,
#             ),
#             (
#                 1152,
#                 1152,
#             ),
#             (
#                 1280,
#                 1280,
#             ),
#             (
#                 1408,
#                 1408,
#             ),
#             (
#                 1536,
#                 1536,
#             ),
#         ],
#         keep_ratio=True),
#     dict(type='RandomFlip', prob=0.0),
#     dict(type='PackDetInputs'),
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='Resize', scale=(
#         1024,
#         1024,
#     ), keep_ratio=True),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         type='PackDetInputs',
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         )),
# ]
# train_dataloader = dict(
#     batch_size=2,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='InfiniteSampler', shuffle=True),
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='../data/input',
#         ann_file='coco_annotations_train_all.json',
#         data_prefix=dict(img='train'),
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True,
#                 poly2mask=True),
#             dict(
#                 type='RandomChoiceResize',
#                 scales=[
#                     (
#                         640,
#                         640,
#                     ),
#                     (
#                         768,
#                         768,
#                     ),
#                     (
#                         896,
#                         896,
#                     ),
#                     (
#                         1024,
#                         1024,
#                     ),
#                     (
#                         1152,
#                         1152,
#                     ),
#                     (
#                         1280,
#                         1280,
#                     ),
#                     (
#                         1408,
#                         1408,
#                     ),
#                     (
#                         1536,
#                         1536,
#                     ),
#                 ],
#                 keep_ratio=True),
#             dict(type='RandomFlip', prob=0.0),
#             dict(type='PackDetInputs'),
#         ],
#         backend_args=None,
#         metainfo=dict(classes=('blood_vessel', ))))
# val_dataloader = None
# test_dataloader = None
# val_evaluator = None
# test_evaluator = None
# train_cfg = dict(type='IterBasedTrainLoop', max_iters=10000, val_interval=500)
# val_cfg = None
# test_cfg = None
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=0.001, by_epoch=False, begin=0,
#         end=1000),
#     dict(
#         type='CosineAnnealingLR',
#         T_max=9000,
#         by_epoch=False,
#         begin=1000,
#         end=10000),
# ]
# optim_wrapper = dict(
#     type='AmpOptimWrapper',
#     optimizer=dict(
#         type='AdamW', lr=0.0002, betas=(
#             0.9,
#             0.999,
#         ), weight_decay=0.05),
#     constructor='LearningRateDecayOptimizerConstructor',
#     paramwise_cfg=dict(decay_rate=0.7, decay_type='layer_wise', num_layers=6))
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=100),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(type='CheckpointHook', interval=0),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='DetVisualizationHook'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ],
#     name='visualizer')
# log_processor = dict(by_epoch=False)
# log_level = 'INFO'
# load_from = '/notebooks/data/output/base_all/exp130_convnext_all/epoch_1.pth'
# resume = False
# custom_imports = dict(
#     imports=[
#         'mmpretrain.models',
#     ], allow_failed_imports=False)
# checkpoint_file = 'https://download.openmmlab.com/mmclassification/v0/convnext/downstream/convnext-tiny_3rdparty_32xb128-noema_in1k_20220301-795e9634.pth'
# max_epochs = 36
# metainfo = dict(classes=('blood_vessel', ))
# work_dir = '../data/output/convnext_all_pseudo09'
#
# 07/25 05:16:51 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 07/25 05:16:51 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------

# %%
seed_everything(CFG.general.seed, workers=True)
runner.train()
# Out:
# Global seed set to 0
# loading annotations into memory...
# Done (t=0.61s)
# creating index...
# index created!
# 07/25 05:16:55 - mmengine - INFO - self.paramwise_cfg is {'decay_rate': 0.7, 'decay_type': 'layer_wise', 'num_layers': 6}
# 07/25 05:16:55 - mmengine - INFO - Build LearningRateDecayOptimizerConstructor  layer_wise 0.7 - 8
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.0.0.weight as id 0
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.0.0.bias as id 0
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.0.1.weight as id 0
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.0.1.bias as id 0
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.1.0.weight as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.1.0.bias as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.1.1.weight as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.1.1.bias as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.2.0.weight as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.2.0.bias as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.2.1.weight as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.2.1.bias as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.3.0.weight as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.3.0.bias as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.3.1.weight as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.downsample_layers.3.1.bias as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.0.gamma as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.0.depthwise_conv.weight as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.0.depthwise_conv.bias as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.0.norm.weight as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.0.norm.bias as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.0.pointwise_conv1.weight as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.0.pointwise_conv1.bias as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.0.pointwise_conv2.weight as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.0.pointwise_conv2.bias as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.1.gamma as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.1.depthwise_conv.weight as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.1.depthwise_conv.bias as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.1.norm.weight as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.1.norm.bias as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.1.pointwise_conv1.weight as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.1.pointwise_conv1.bias as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.1.pointwise_conv2.weight as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.1.pointwise_conv2.bias as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.2.gamma as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.2.depthwise_conv.weight as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.2.depthwise_conv.bias as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.2.norm.weight as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.2.norm.bias as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.2.pointwise_conv1.weight as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.2.pointwise_conv1.bias as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.2.pointwise_conv2.weight as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.0.2.pointwise_conv2.bias as id 1
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.0.gamma as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.0.depthwise_conv.weight as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.0.depthwise_conv.bias as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.0.norm.weight as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.0.norm.bias as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.0.pointwise_conv1.weight as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.0.pointwise_conv1.bias as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.0.pointwise_conv2.weight as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.0.pointwise_conv2.bias as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.1.gamma as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.1.depthwise_conv.weight as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.1.depthwise_conv.bias as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.1.norm.weight as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.1.norm.bias as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.1.pointwise_conv1.weight as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.1.pointwise_conv1.bias as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.1.pointwise_conv2.weight as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.1.pointwise_conv2.bias as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.2.gamma as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.2.depthwise_conv.weight as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.2.depthwise_conv.bias as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.2.norm.weight as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.2.norm.bias as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.2.pointwise_conv1.weight as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.2.pointwise_conv1.bias as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.2.pointwise_conv2.weight as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.1.2.pointwise_conv2.bias as id 2
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.0.gamma as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.0.depthwise_conv.weight as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.0.depthwise_conv.bias as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.0.norm.weight as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.0.norm.bias as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.0.pointwise_conv1.weight as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.0.pointwise_conv1.bias as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.0.pointwise_conv2.weight as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.0.pointwise_conv2.bias as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.1.gamma as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.1.depthwise_conv.weight as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.1.depthwise_conv.bias as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.1.norm.weight as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.1.norm.bias as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.1.pointwise_conv1.weight as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.1.pointwise_conv1.bias as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.1.pointwise_conv2.weight as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.1.pointwise_conv2.bias as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.2.gamma as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.2.depthwise_conv.weight as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.2.depthwise_conv.bias as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.2.norm.weight as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.2.norm.bias as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.2.pointwise_conv1.weight as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.2.pointwise_conv1.bias as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.2.pointwise_conv2.weight as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.2.pointwise_conv2.bias as id 3
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.3.gamma as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.3.depthwise_conv.weight as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.3.depthwise_conv.bias as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.3.norm.weight as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.3.norm.bias as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.3.pointwise_conv1.weight as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.3.pointwise_conv1.bias as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.3.pointwise_conv2.weight as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.3.pointwise_conv2.bias as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.4.gamma as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.4.depthwise_conv.weight as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.4.depthwise_conv.bias as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.4.norm.weight as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.4.norm.bias as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.4.pointwise_conv1.weight as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.4.pointwise_conv1.bias as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.4.pointwise_conv2.weight as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.4.pointwise_conv2.bias as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.5.gamma as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.5.depthwise_conv.weight as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.5.depthwise_conv.bias as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.5.norm.weight as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.5.norm.bias as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.5.pointwise_conv1.weight as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.5.pointwise_conv1.bias as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.5.pointwise_conv2.weight as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.5.pointwise_conv2.bias as id 4
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.6.gamma as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.6.depthwise_conv.weight as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.6.depthwise_conv.bias as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.6.norm.weight as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.6.norm.bias as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.6.pointwise_conv1.weight as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.6.pointwise_conv1.bias as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.6.pointwise_conv2.weight as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.6.pointwise_conv2.bias as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.7.gamma as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.7.depthwise_conv.weight as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.7.depthwise_conv.bias as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.7.norm.weight as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.7.norm.bias as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.7.pointwise_conv1.weight as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.7.pointwise_conv1.bias as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.7.pointwise_conv2.weight as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.7.pointwise_conv2.bias as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.8.gamma as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.8.depthwise_conv.weight as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.8.depthwise_conv.bias as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.8.norm.weight as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.8.norm.bias as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.8.pointwise_conv1.weight as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.8.pointwise_conv1.bias as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.8.pointwise_conv2.weight as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.2.8.pointwise_conv2.bias as id 5
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.0.gamma as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.0.depthwise_conv.weight as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.0.depthwise_conv.bias as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.0.norm.weight as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.0.norm.bias as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.0.pointwise_conv1.weight as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.0.pointwise_conv1.bias as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.0.pointwise_conv2.weight as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.0.pointwise_conv2.bias as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.1.gamma as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.1.depthwise_conv.weight as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.1.depthwise_conv.bias as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.1.norm.weight as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.1.norm.bias as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.1.pointwise_conv1.weight as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.1.pointwise_conv1.bias as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.1.pointwise_conv2.weight as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.1.pointwise_conv2.bias as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.2.gamma as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.2.depthwise_conv.weight as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.2.depthwise_conv.bias as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.2.norm.weight as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.2.norm.bias as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.2.pointwise_conv1.weight as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.2.pointwise_conv1.bias as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.2.pointwise_conv2.weight as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.stages.3.2.pointwise_conv2.bias as id 6
# 07/25 05:16:55 - mmengine - INFO - set param backbone.norm0.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param backbone.norm0.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param backbone.norm1.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param backbone.norm1.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param backbone.norm2.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param backbone.norm2.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param backbone.norm3.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param backbone.norm3.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.lateral_convs.0.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.lateral_convs.0.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.lateral_convs.1.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.lateral_convs.1.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.lateral_convs.2.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.lateral_convs.2.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.lateral_convs.3.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.lateral_convs.3.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.fpn_convs.0.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.fpn_convs.0.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.fpn_convs.1.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.fpn_convs.1.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.fpn_convs.2.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.fpn_convs.2.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.fpn_convs.3.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param neck.fpn_convs.3.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param rpn_head.rpn_conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param rpn_head.rpn_conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param rpn_head.rpn_cls.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param rpn_head.rpn_cls.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param rpn_head.rpn_reg.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param rpn_head.rpn_reg.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.fc_cls.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.fc_cls.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.fc_reg.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.fc_reg.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.0.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.0.bn.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.0.bn.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.1.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.1.bn.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.1.bn.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.2.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.2.bn.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.2.bn.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.3.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.3.bn.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.3.bn.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.shared_fcs.0.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.0.shared_fcs.0.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.fc_cls.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.fc_cls.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.fc_reg.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.fc_reg.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.0.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.0.bn.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.0.bn.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.1.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.1.bn.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.1.bn.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.2.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.2.bn.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.2.bn.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.3.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.3.bn.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.3.bn.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.shared_fcs.0.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.1.shared_fcs.0.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.fc_cls.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.fc_cls.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.fc_reg.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.fc_reg.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.0.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.0.bn.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.0.bn.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.1.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.1.bn.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.1.bn.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.2.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.2.bn.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.2.bn.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.3.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.3.bn.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.3.bn.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.shared_fcs.0.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.bbox_head.2.shared_fcs.0.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.0.convs.0.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.0.convs.0.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.0.convs.1.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.0.convs.1.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.0.convs.2.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.0.convs.2.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.0.convs.3.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.0.convs.3.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.0.upsample.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.0.upsample.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.0.conv_logits.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.0.conv_logits.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.1.convs.0.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.1.convs.0.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.1.convs.1.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.1.convs.1.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.1.convs.2.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.1.convs.2.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.1.convs.3.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.1.convs.3.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.1.upsample.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.1.upsample.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.1.conv_logits.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.1.conv_logits.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.2.convs.0.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.2.convs.0.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.2.convs.1.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.2.convs.1.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.2.convs.2.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.2.convs.2.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.2.convs.3.conv.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.2.convs.3.conv.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.2.upsample.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.2.upsample.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.2.conv_logits.weight as id 7
# 07/25 05:16:55 - mmengine - INFO - set param roi_head.mask_head.2.conv_logits.bias as id 7
# 07/25 05:16:55 - mmengine - INFO - Param groups = {
#   "layer_0_decay": {
#     "param_names": [
#       "backbone.downsample_layers.0.0.weight"
#     ],
#     "lr_scale": 0.08235429999999996,
#     "lr": 1.6470859999999992e-05,
#     "weight_decay": 0.05
#   },
#   "layer_0_no_decay": {
#     "param_names": [
#       "backbone.downsample_layers.0.0.bias",
#       "backbone.downsample_layers.0.1.weight",
#       "backbone.downsample_layers.0.1.bias"
#     ],
#     "lr_scale": 0.08235429999999996,
#     "lr": 1.6470859999999992e-05,
#     "weight_decay": 0.0
#   },
#   "layer_2_no_decay": {
#     "param_names": [
#       "backbone.downsample_layers.1.0.weight",
#       "backbone.downsample_layers.1.0.bias",
#       "backbone.downsample_layers.1.1.bias",
#       "backbone.stages.1.0.gamma",
#       "backbone.stages.1.0.depthwise_conv.bias",
#       "backbone.stages.1.0.norm.weight",
#       "backbone.stages.1.0.norm.bias",
#       "backbone.stages.1.0.pointwise_conv1.bias",
#       "backbone.stages.1.0.pointwise_conv2.bias",
#       "backbone.stages.1.1.gamma",
#       "backbone.stages.1.1.depthwise_conv.bias",
#       "backbone.stages.1.1.norm.weight",
#       "backbone.stages.1.1.norm.bias",
#       "backbone.stages.1.1.pointwise_conv1.bias",
#       "backbone.stages.1.1.pointwise_conv2.bias",
#       "backbone.stages.1.2.gamma",
#       "backbone.stages.1.2.depthwise_conv.bias",
#       "backbone.stages.1.2.norm.weight",
#       "backbone.stages.1.2.norm.bias",
#       "backbone.stages.1.2.pointwise_conv1.bias",
#       "backbone.stages.1.2.pointwise_conv2.bias"
#     ],
#     "lr_scale": 0.16806999999999994,
#     "lr": 3.361399999999999e-05,
#     "weight_decay": 0.0
#   },
#   "layer_2_decay": {
#     "param_names": [
#       "backbone.downsample_layers.1.1.weight",
#       "backbone.stages.1.0.depthwise_conv.weight",
#       "backbone.stages.1.0.pointwise_conv1.weight",
#       "backbone.stages.1.0.pointwise_conv2.weight",
#       "backbone.stages.1.1.depthwise_conv.weight",
#       "backbone.stages.1.1.pointwise_conv1.weight",
#       "backbone.stages.1.1.pointwise_conv2.weight",
#       "backbone.stages.1.2.depthwise_conv.weight",
#       "backbone.stages.1.2.pointwise_conv1.weight",
#       "backbone.stages.1.2.pointwise_conv2.weight"
#     ],
#     "lr_scale": 0.16806999999999994,
#     "lr": 3.361399999999999e-05,
#     "weight_decay": 0.05
#   },
#   "layer_3_no_decay": {
#     "param_names": [
#       "backbone.downsample_layers.2.0.weight",
#       "backbone.downsample_layers.2.0.bias",
#       "backbone.downsample_layers.2.1.bias",
#       "backbone.stages.2.0.gamma",
#       "backbone.stages.2.0.depthwise_conv.bias",
#       "backbone.stages.2.0.norm.weight",
#       "backbone.stages.2.0.norm.bias",
#       "backbone.stages.2.0.pointwise_conv1.bias",
#       "backbone.stages.2.0.pointwise_conv2.bias",
#       "backbone.stages.2.1.gamma",
#       "backbone.stages.2.1.depthwise_conv.bias",
#       "backbone.stages.2.1.norm.weight",
#       "backbone.stages.2.1.norm.bias",
#       "backbone.stages.2.1.pointwise_conv1.bias",
#       "backbone.stages.2.1.pointwise_conv2.bias",
#       "backbone.stages.2.2.gamma",
#       "backbone.stages.2.2.depthwise_conv.bias",
#       "backbone.stages.2.2.norm.weight",
#       "backbone.stages.2.2.norm.bias",
#       "backbone.stages.2.2.pointwise_conv1.bias",
#       "backbone.stages.2.2.pointwise_conv2.bias"
#     ],
#     "lr_scale": 0.24009999999999995,
#     "lr": 4.801999999999999e-05,
#     "weight_decay": 0.0
#   },
#   "layer_3_decay": {
#     "param_names": [
#       "backbone.downsample_layers.2.1.weight",
#       "backbone.stages.2.0.depthwise_conv.weight",
#       "backbone.stages.2.0.pointwise_conv1.weight",
#       "backbone.stages.2.0.pointwise_conv2.weight",
#       "backbone.stages.2.1.depthwise_conv.weight",
#       "backbone.stages.2.1.pointwise_conv1.weight",
#       "backbone.stages.2.1.pointwise_conv2.weight",
#       "backbone.stages.2.2.depthwise_conv.weight",
#       "backbone.stages.2.2.pointwise_conv1.weight",
#       "backbone.stages.2.2.pointwise_conv2.weight"
#     ],
#     "lr_scale": 0.24009999999999995,
#     "lr": 4.801999999999999e-05,
#     "weight_decay": 0.05
#   },
#   "layer_6_no_decay": {
#     "param_names": [
#       "backbone.downsample_layers.3.0.weight",
#       "backbone.downsample_layers.3.0.bias",
#       "backbone.downsample_layers.3.1.bias",
#       "backbone.stages.3.0.gamma",
#       "backbone.stages.3.0.depthwise_conv.bias",
#       "backbone.stages.3.0.norm.weight",
#       "backbone.stages.3.0.norm.bias",
#       "backbone.stages.3.0.pointwise_conv1.bias",
#       "backbone.stages.3.0.pointwise_conv2.bias",
#       "backbone.stages.3.1.gamma",
#       "backbone.stages.3.1.depthwise_conv.bias",
#       "backbone.stages.3.1.norm.weight",
#       "backbone.stages.3.1.norm.bias",
#       "backbone.stages.3.1.pointwise_conv1.bias",
#       "backbone.stages.3.1.pointwise_conv2.bias",
#       "backbone.stages.3.2.gamma",
#       "backbone.stages.3.2.depthwise_conv.bias",
#       "backbone.stages.3.2.norm.weight",
#       "backbone.stages.3.2.norm.bias",
#       "backbone.stages.3.2.pointwise_conv1.bias",
#       "backbone.stages.3.2.pointwise_conv2.bias"
#     ],
#     "lr_scale": 0.7,
#     "lr": 0.00014,
#     "weight_decay": 0.0
#   },
#   "layer_6_decay": {
#     "param_names": [
#       "backbone.downsample_layers.3.1.weight",
#       "backbone.stages.3.0.depthwise_conv.weight",
#       "backbone.stages.3.0.pointwise_conv1.weight",
#       "backbone.stages.3.0.pointwise_conv2.weight",
#       "backbone.stages.3.1.depthwise_conv.weight",
#       "backbone.stages.3.1.pointwise_conv1.weight",
#       "backbone.stages.3.1.pointwise_conv2.weight",
#       "backbone.stages.3.2.depthwise_conv.weight",
#       "backbone.stages.3.2.pointwise_conv1.weight",
#       "backbone.stages.3.2.pointwise_conv2.weight"
#     ],
#     "lr_scale": 0.7,
#     "lr": 0.00014,
#     "weight_decay": 0.05
#   },
#   "layer_1_no_decay": {
#     "param_names": [
#       "backbone.stages.0.0.gamma",
#       "backbone.stages.0.0.depthwise_conv.bias",
#       "backbone.stages.0.0.norm.weight",
#       "backbone.stages.0.0.norm.bias",
#       "backbone.stages.0.0.pointwise_conv1.bias",
#       "backbone.stages.0.0.pointwise_conv2.bias",
#       "backbone.stages.0.1.gamma",
#       "backbone.stages.0.1.depthwise_conv.bias",
#       "backbone.stages.0.1.norm.weight",
#       "backbone.stages.0.1.norm.bias",
#       "backbone.stages.0.1.pointwise_conv1.bias",
#       "backbone.stages.0.1.pointwise_conv2.bias",
#       "backbone.stages.0.2.gamma",
#       "backbone.stages.0.2.depthwise_conv.bias",
#       "backbone.stages.0.2.norm.weight",
#       "backbone.stages.0.2.norm.bias",
#       "backbone.stages.0.2.pointwise_conv1.bias",
#       "backbone.stages.0.2.pointwise_conv2.bias"
#     ],
#     "lr_scale": 0.11764899999999996,
#     "lr": 2.3529799999999993e-05,
#     "weight_decay": 0.0
#   },
#   "layer_1_decay": {
#     "param_names": [
#       "backbone.stages.0.0.depthwise_conv.weight",
#       "backbone.stages.0.0.pointwise_conv1.weight",
#       "backbone.stages.0.0.pointwise_conv2.weight",
#       "backbone.stages.0.1.depthwise_conv.weight",
#       "backbone.stages.0.1.pointwise_conv1.weight",
#       "backbone.stages.0.1.pointwise_conv2.weight",
#       "backbone.stages.0.2.depthwise_conv.weight",
#       "backbone.stages.0.2.pointwise_conv1.weight",
#       "backbone.stages.0.2.pointwise_conv2.weight"
#     ],
#     "lr_scale": 0.11764899999999996,
#     "lr": 2.3529799999999993e-05,
#     "weight_decay": 0.05
#   },
#   "layer_4_no_decay": {
#     "param_names": [
#       "backbone.stages.2.3.gamma",
#       "backbone.stages.2.3.depthwise_conv.bias",
#       "backbone.stages.2.3.norm.weight",
#       "backbone.stages.2.3.norm.bias",
#       "backbone.stages.2.3.pointwise_conv1.bias",
#       "backbone.stages.2.3.pointwise_conv2.bias",
#       "backbone.stages.2.4.gamma",
#       "backbone.stages.2.4.depthwise_conv.bias",
#       "backbone.stages.2.4.norm.weight",
#       "backbone.stages.2.4.norm.bias",
#       "backbone.stages.2.4.pointwise_conv1.bias",
#       "backbone.stages.2.4.pointwise_conv2.bias",
#       "backbone.stages.2.5.gamma",
#       "backbone.stages.2.5.depthwise_conv.bias",
#       "backbone.stages.2.5.norm.weight",
#       "backbone.stages.2.5.norm.bias",
#       "backbone.stages.2.5.pointwise_conv1.bias",
#       "backbone.stages.2.5.pointwise_conv2.bias"
#     ],
#     "lr_scale": 0.3429999999999999,
#     "lr": 6.859999999999999e-05,
#     "weight_decay": 0.0
#   },
#   "layer_4_decay": {
#     "param_names": [
#       "backbone.stages.2.3.depthwise_conv.weight",
#       "backbone.stages.2.3.pointwise_conv1.weight",
#       "backbone.stages.2.3.pointwise_conv2.weight",
#       "backbone.stages.2.4.depthwise_conv.weight",
#       "backbone.stages.2.4.pointwise_conv1.weight",
#       "backbone.stages.2.4.pointwise_conv2.weight",
#       "backbone.stages.2.5.depthwise_conv.weight",
#       "backbone.stages.2.5.pointwise_conv1.weight",
#       "backbone.stages.2.5.pointwise_conv2.weight"
#     ],
#     "lr_scale": 0.3429999999999999,
#     "lr": 6.859999999999999e-05,
#     "weight_decay": 0.05
#   },
#   "layer_5_no_decay": {
#     "param_names": [
#       "backbone.stages.2.6.gamma",
#       "backbone.stages.2.6.depthwise_conv.bias",
#       "backbone.stages.2.6.norm.weight",
#       "backbone.stages.2.6.norm.bias",
#       "backbone.stages.2.6.pointwise_conv1.bias",
#       "backbone.stages.2.6.pointwise_conv2.bias",
#       "backbone.stages.2.7.gamma",
#       "backbone.stages.2.7.depthwise_conv.bias",
#       "backbone.stages.2.7.norm.weight",
#       "backbone.stages.2.7.norm.bias",
#       "backbone.stages.2.7.pointwise_conv1.bias",
#       "backbone.stages.2.7.pointwise_conv2.bias",
#       "backbone.stages.2.8.gamma",
#       "backbone.stages.2.8.depthwise_conv.bias",
#       "backbone.stages.2.8.norm.weight",
#       "backbone.stages.2.8.norm.bias",
#       "backbone.stages.2.8.pointwise_conv1.bias",
#       "backbone.stages.2.8.pointwise_conv2.bias"
#     ],
#     "lr_scale": 0.48999999999999994,
#     "lr": 9.8e-05,
#     "weight_decay": 0.0
#   },
#   "layer_5_decay": {
#     "param_names": [
#       "backbone.stages.2.6.depthwise_conv.weight",
#       "backbone.stages.2.6.pointwise_conv1.weight",
#       "backbone.stages.2.6.pointwise_conv2.weight",
#       "backbone.stages.2.7.depthwise_conv.weight",
#       "backbone.stages.2.7.pointwise_conv1.weight",
#       "backbone.stages.2.7.pointwise_conv2.weight",
#       "backbone.stages.2.8.depthwise_conv.weight",
#       "backbone.stages.2.8.pointwise_conv1.weight",
#       "backbone.stages.2.8.pointwise_conv2.weight"
#     ],
#     "lr_scale": 0.48999999999999994,
#     "lr": 9.8e-05,
#     "weight_decay": 0.05
#   },
#   "layer_7_no_decay": {
#     "param_names": [
#       "backbone.norm0.weight",
#       "backbone.norm0.bias",
#       "backbone.norm1.weight",
#       "backbone.norm1.bias",
#       "backbone.norm2.weight",
#       "backbone.norm2.bias",
#       "backbone.norm3.weight",
#       "backbone.norm3.bias",
#       "neck.lateral_convs.0.conv.bias",
#       "neck.lateral_convs.1.conv.bias",
#       "neck.lateral_convs.2.conv.bias",
#       "neck.lateral_convs.3.conv.bias",
#       "neck.fpn_convs.0.conv.bias",
#       "neck.fpn_convs.1.conv.bias",
#       "neck.fpn_convs.2.conv.bias",
#       "neck.fpn_convs.3.conv.bias",
#       "rpn_head.rpn_conv.bias",
#       "rpn_head.rpn_cls.bias",
#       "rpn_head.rpn_reg.bias",
#       "roi_head.bbox_head.0.fc_cls.bias",
#       "roi_head.bbox_head.0.fc_reg.bias",
#       "roi_head.bbox_head.0.shared_convs.0.bn.weight",
#       "roi_head.bbox_head.0.shared_convs.0.bn.bias",
#       "roi_head.bbox_head.0.shared_convs.1.bn.weight",
#       "roi_head.bbox_head.0.shared_convs.1.bn.bias",
#       "roi_head.bbox_head.0.shared_convs.2.bn.weight",
#       "roi_head.bbox_head.0.shared_convs.2.bn.bias",
#       "roi_head.bbox_head.0.shared_convs.3.bn.weight",
#       "roi_head.bbox_head.0.shared_convs.3.bn.bias",
#       "roi_head.bbox_head.0.shared_fcs.0.bias",
#       "roi_head.bbox_head.1.fc_cls.bias",
#       "roi_head.bbox_head.1.fc_reg.bias",
#       "roi_head.bbox_head.1.shared_convs.0.bn.weight",
#       "roi_head.bbox_head.1.shared_convs.0.bn.bias",
#       "roi_head.bbox_head.1.shared_convs.1.bn.weight",
#       "roi_head.bbox_head.1.shared_convs.1.bn.bias",
#       "roi_head.bbox_head.1.shared_convs.2.bn.weight",
#       "roi_head.bbox_head.1.shared_convs.2.bn.bias",
#       "roi_head.bbox_head.1.shared_convs.3.bn.weight",
#       "roi_head.bbox_head.1.shared_convs.3.bn.bias",
#       "roi_head.bbox_head.1.shared_fcs.0.bias",
#       "roi_head.bbox_head.2.fc_cls.bias",
#       "roi_head.bbox_head.2.fc_reg.bias",
#       "roi_head.bbox_head.2.shared_convs.0.bn.weight",
#       "roi_head.bbox_head.2.shared_convs.0.bn.bias",
#       "roi_head.bbox_head.2.shared_convs.1.bn.weight",
#       "roi_head.bbox_head.2.shared_convs.1.bn.bias",
#       "roi_head.bbox_head.2.shared_convs.2.bn.weight",
#       "roi_head.bbox_head.2.shared_convs.2.bn.bias",
#       "roi_head.bbox_head.2.shared_convs.3.bn.weight",
#       "roi_head.bbox_head.2.shared_convs.3.bn.bias",
#       "roi_head.bbox_head.2.shared_fcs.0.bias",
#       "roi_head.mask_head.0.convs.0.conv.bias",
#       "roi_head.mask_head.0.convs.1.conv.bias",
#       "roi_head.mask_head.0.convs.2.conv.bias",
#       "roi_head.mask_head.0.convs.3.conv.bias",
#       "roi_head.mask_head.0.upsample.bias",
#       "roi_head.mask_head.0.conv_logits.bias",
#       "roi_head.mask_head.1.convs.0.conv.bias",
#       "roi_head.mask_head.1.convs.1.conv.bias",
#       "roi_head.mask_head.1.convs.2.conv.bias",
#       "roi_head.mask_head.1.convs.3.conv.bias",
#       "roi_head.mask_head.1.upsample.bias",
#       "roi_head.mask_head.1.conv_logits.bias",
#       "roi_head.mask_head.2.convs.0.conv.bias",
#       "roi_head.mask_head.2.convs.1.conv.bias",
#       "roi_head.mask_head.2.convs.2.conv.bias",
#       "roi_head.mask_head.2.convs.3.conv.bias",
#       "roi_head.mask_head.2.upsample.bias",
#       "roi_head.mask_head.2.conv_logits.bias"
#     ],
#     "lr_scale": 1.0,
#     "lr": 0.0002,
#     "weight_decay": 0.0
#   },
#   "layer_7_decay": {
#     "param_names": [
#       "neck.lateral_convs.0.conv.weight",
#       "neck.lateral_convs.1.conv.weight",
#       "neck.lateral_convs.2.conv.weight",
#       "neck.lateral_convs.3.conv.weight",
#       "neck.fpn_convs.0.conv.weight",
#       "neck.fpn_convs.1.conv.weight",
#       "neck.fpn_convs.2.conv.weight",
#       "neck.fpn_convs.3.conv.weight",
#       "rpn_head.rpn_conv.weight",
#       "rpn_head.rpn_cls.weight",
#       "rpn_head.rpn_reg.weight",
#       "roi_head.bbox_head.0.fc_cls.weight",
#       "roi_head.bbox_head.0.fc_reg.weight",
#       "roi_head.bbox_head.0.shared_convs.0.conv.weight",
#       "roi_head.bbox_head.0.shared_convs.1.conv.weight",
#       "roi_head.bbox_head.0.shared_convs.2.conv.weight",
#       "roi_head.bbox_head.0.shared_convs.3.conv.weight",
#       "roi_head.bbox_head.0.shared_fcs.0.weight",
#       "roi_head.bbox_head.1.fc_cls.weight",
#       "roi_head.bbox_head.1.fc_reg.weight",
#       "roi_head.bbox_head.1.shared_convs.0.conv.weight",
#       "roi_head.bbox_head.1.shared_convs.1.conv.weight",
#       "roi_head.bbox_head.1.shared_convs.2.conv.weight",
#       "roi_head.bbox_head.1.shared_convs.3.conv.weight",
#       "roi_head.bbox_head.1.shared_fcs.0.weight",
#       "roi_head.bbox_head.2.fc_cls.weight",
#       "roi_head.bbox_head.2.fc_reg.weight",
#       "roi_head.bbox_head.2.shared_convs.0.conv.weight",
#       "roi_head.bbox_head.2.shared_convs.1.conv.weight",
#       "roi_head.bbox_head.2.shared_convs.2.conv.weight",
#       "roi_head.bbox_head.2.shared_convs.3.conv.weight",
#       "roi_head.bbox_head.2.shared_fcs.0.weight",
#       "roi_head.mask_head.0.convs.0.conv.weight",
#       "roi_head.mask_head.0.convs.1.conv.weight",
#       "roi_head.mask_head.0.convs.2.conv.weight",
#       "roi_head.mask_head.0.convs.3.conv.weight",
#       "roi_head.mask_head.0.upsample.weight",
#       "roi_head.mask_head.0.conv_logits.weight",
#       "roi_head.mask_head.1.convs.0.conv.weight",
#       "roi_head.mask_head.1.convs.1.conv.weight",
#       "roi_head.mask_head.1.convs.2.conv.weight",
#       "roi_head.mask_head.1.convs.3.conv.weight",
#       "roi_head.mask_head.1.upsample.weight",
#       "roi_head.mask_head.1.conv_logits.weight",
#       "roi_head.mask_head.2.convs.0.conv.weight",
#       "roi_head.mask_head.2.convs.1.conv.weight",
#       "roi_head.mask_head.2.convs.2.conv.weight",
#       "roi_head.mask_head.2.convs.3.conv.weight",
#       "roi_head.mask_head.2.upsample.weight",
#       "roi_head.mask_head.2.conv_logits.weight"
#     ],
#     "lr_scale": 1.0,
#     "lr": 0.0002,
#     "weight_decay": 0.05
#   }
# }
# 07/25 05:16:56 - mmengine - INFO - load backbone. in model from: https://download.openmmlab.com/mmclassification/v0/convnext/downstream/convnext-tiny_3rdparty_32xb128-noema_in1k_20220301-795e9634.pth
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmclassification/v0/convnext/downstream/convnext-tiny_3rdparty_32xb128-noema_in1k_20220301-795e9634.pth
# Downloading: "https://download.openmmlab.com/mmclassification/v0/convnext/downstream/convnext-tiny_3rdparty_32xb128-noema_in1k_20220301-795e9634.pth" to /root/.cache/torch/hub/checkpoints/convnext-tiny_3rdparty_32xb128-noema_in1k_20220301-795e9634.pth
# 07/25 05:18:13 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: norm0.weight, norm0.bias, norm1.weight, norm1.bias, norm2.weight, norm2.bias, norm3.weight, norm3.bias
#
# Loads checkpoint by local backend from path: /notebooks/data/output/base_all/exp130_convnext_all/epoch_1.pth
# 07/25 05:18:18 - mmengine - INFO - Load checkpoint from /notebooks/data/output/base_all/exp130_convnext_all/epoch_1.pth
# 07/25 05:18:18 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 07/25 05:18:18 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 07/25 05:18:18 - mmengine - INFO - Checkpoints will be saved to /notebooks/data/output/convnext_all_pseudo09.
# 07/25 05:19:15 - mmengine - INFO - Iter(train) [  100/10000]  base_lr: 2.0000e-05 lr: 1.6471e-06  eta: 1:33:46  time: 0.5092  data_time: 0.0408  memory: 10530  loss: 1.0725  loss_rpn_cls: 0.0275  loss_rpn_bbox: 0.0160  s0.loss_cls: 0.1534  s0.acc: 98.0469  s0.loss_bbox: 0.2574  s0.loss_mask: 0.1813  s1.loss_cls: 0.0809  s1.acc: 98.8281  s1.loss_bbox: 0.1242  s1.loss_mask: 0.0936  s2.loss_cls: 0.0436  s2.acc: 96.9727  s2.loss_bbox: 0.0512  s2.loss_mask: 0.0435
# 07/25 05:20:06 - mmengine - INFO - Iter(train) [  200/10000]  base_lr: 4.0000e-05 lr: 3.2942e-06  eta: 1:28:14  time: 0.5578  data_time: 0.0552  memory: 10518  loss: 1.0174  loss_rpn_cls: 0.0230  loss_rpn_bbox: 0.0149  s0.loss_cls: 0.1342  s0.acc: 94.3359  s0.loss_bbox: 0.2528  s0.loss_mask: 0.1718  s1.loss_cls: 0.0741  s1.acc: 93.9000  s1.loss_bbox: 0.1228  s1.loss_mask: 0.0904  s2.loss_cls: 0.0388  s2.acc: 93.9759  s2.loss_bbox: 0.0515  s2.loss_mask: 0.0431
# 07/25 05:20:57 - mmengine - INFO - Iter(train) [  300/10000]  base_lr: 6.0000e-05 lr: 4.9413e-06  eta: 1:25:53  time: 0.4599  data_time: 0.0576  memory: 10532  loss: 0.8656  loss_rpn_cls: 0.0159  loss_rpn_bbox: 0.0130  s0.loss_cls: 0.1245  s0.acc: 96.3867  s0.loss_bbox: 0.1988  s0.loss_mask: 0.1498  s1.loss_cls: 0.0618  s1.acc: 96.0746  s1.loss_bbox: 0.1008  s1.loss_mask: 0.0834  s2.loss_cls: 0.0325  s2.acc: 97.0472  s2.loss_bbox: 0.0444  s2.loss_mask: 0.0407
# 07/25 05:21:49 - mmengine - INFO - Iter(train) [  400/10000]  base_lr: 8.0000e-05 lr: 6.5883e-06  eta: 1:24:23  time: 0.4268  data_time: 0.0374  memory: 10547  loss: 0.7916  loss_rpn_cls: 0.0177  loss_rpn_bbox: 0.0084  s0.loss_cls: 0.1170  s0.acc: 94.7266  s0.loss_bbox: 0.1781  s0.loss_mask: 0.1360  s1.loss_cls: 0.0675  s1.acc: 94.7266  s1.loss_bbox: 0.0883  s1.loss_mask: 0.0733  s2.loss_cls: 0.0352  s2.acc: 95.7031  s2.loss_bbox: 0.0363  s2.loss_mask: 0.0338
# 07/25 05:22:42 - mmengine - INFO - Iter(train) [  500/10000]  base_lr: 1.0000e-04 lr: 8.2354e-06  eta: 1:23:33  time: 0.4961  data_time: 0.0418  memory: 10521  loss: 0.8543  loss_rpn_cls: 0.0165  loss_rpn_bbox: 0.0122  s0.loss_cls: 0.1073  s0.acc: 95.1172  s0.loss_bbox: 0.2056  s0.loss_mask: 0.1553  s1.loss_cls: 0.0543  s1.acc: 95.2148  s1.loss_bbox: 0.1002  s1.loss_mask: 0.0859  s2.loss_cls: 0.0323  s2.acc: 94.0430  s2.loss_bbox: 0.0442  s2.loss_mask: 0.0404
# 07/25 05:23:31 - mmengine - INFO - Iter(train) [  600/10000]  base_lr: 1.2000e-04 lr: 9.8825e-06  eta: 1:21:50  time: 0.5449  data_time: 0.0706  memory: 10535  loss: 0.9862  loss_rpn_cls: 0.0172  loss_rpn_bbox: 0.0150  s0.loss_cls: 0.1448  s0.acc: 92.7734  s0.loss_bbox: 0.2187  s0.loss_mask: 0.1754  s1.loss_cls: 0.0742  s1.acc: 93.5547  s1.loss_bbox: 0.1103  s1.loss_mask: 0.0944  s2.loss_cls: 0.0399  s2.acc: 92.1875  s2.loss_bbox: 0.0500  s2.loss_mask: 0.0464
# ...
#           (act): GELU(approximate=none)
#           (pointwise_conv2): Linear(in_features=3072, out_features=768, bias=True)
#           (drop_path): DropPath()
#         )
#         (1): ConvNeXtBlock(
#           (depthwise_conv): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (norm): LayerNorm2d((768,), eps=1e-06, elementwise_affine=True)
#           (pointwise_conv1): Linear(in_features=768, out_features=3072, bias=True)
#           (act): GELU(approximate=none)
#           (pointwise_conv2): Linear(in_features=3072, out_features=768, bias=True)
#           (drop_path): DropPath()
#         )
#         (2): ConvNeXtBlock(
#           (depthwise_conv): Conv2d(768, 768, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), groups=768)
#           (norm): LayerNorm2d((768,), eps=1e-06, elementwise_affine=True)
#           (pointwise_conv1): Linear(in_features=768, out_features=3072, bias=True)
#           (act): GELU(approximate=none)
#           (pointwise_conv2): Linear(in_features=3072, out_features=768, bias=True)
#           (drop_path): DropPath()
#         )
#       )
#     )
#     (norm0): LayerNorm2d((96,), eps=1e-06, elementwise_affine=True)
#     (norm1): LayerNorm2d((192,), eps=1e-06, elementwise_affine=True)
#     (norm2): LayerNorm2d((384,), eps=1e-06, elementwise_affine=True)
#     (norm3): LayerNorm2d((768,), eps=1e-06, elementwise_affine=True)
#   )
#   init_cfg={'type': 'Pretrained', 'checkpoint': 'https://download.openmmlab.com/mmclassification/v0/convnext/downstream/convnext-tiny_3rdparty_32xb128-noema_in1k_20220301-795e9634.pth', 'prefix': 'backbone.'}
#   (neck): FPN(
#     (lateral_convs): ModuleList(
#       (0): ConvModule(
#         (conv): Conv2d(96, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (1): ConvModule(
#         (conv): Conv2d(192, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (2): ConvModule(
#         (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (3): ConvModule(
#         (conv): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#     )
#     (fpn_convs): ModuleList(
#       (0): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (1): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (2): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (3): ConvModule(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#   )
#   init_cfg={'type': 'Xavier', 'layer': 'Conv2d', 'distribution': 'uniform'}
#   (rpn_head): RPNHead(
#     (loss_cls): CrossEntropyLoss(avg_non_ignore=False)
#     (loss_bbox): SmoothL1Loss()
#     (rpn_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (rpn_cls): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#     (rpn_reg): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#   )
#   init_cfg={'type': 'Normal', 'layer': 'Conv2d', 'std': 0.01}
#   (roi_head): CascadeRoIHead(
#     (bbox_roi_extractor): ModuleList(
#       (0): SingleRoIExtractor(
#         (roi_layers): ModuleList(
#           (0): RoIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (1): RoIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (2): RoIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (3): RoIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         )
#       )
#       (1): SingleRoIExtractor(
#         (roi_layers): ModuleList(
#           (0): RoIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (1): RoIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (2): RoIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (3): RoIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         )
#       )
#       (2): SingleRoIExtractor(
#         (roi_layers): ModuleList(
#           (0): RoIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (1): RoIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (2): RoIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (3): RoIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         )
#       )
#     )
#     (bbox_head): ModuleList(
#       (0): ConvFCBBoxHead(
#         (loss_cls): CrossEntropyLoss(avg_non_ignore=False)
#         (loss_bbox): GIoULoss()
#         (fc_cls): Linear(in_features=1024, out_features=2, bias=True)
#         (fc_reg): Linear(in_features=1024, out_features=4, bias=True)
#         (shared_convs): ModuleList(
#           (0): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (2): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (3): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#         )
#         (shared_fcs): ModuleList(
#           (0): Linear(in_features=12544, out_features=1024, bias=True)
#         )
#         (cls_convs): ModuleList()
#         (cls_fcs): ModuleList()
#         (reg_convs): ModuleList()
#         (reg_fcs): ModuleList()
#         (relu): ReLU(inplace=True)
#       )
#       init_cfg=[{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
#       (1): ConvFCBBoxHead(
#         (loss_cls): CrossEntropyLoss(avg_non_ignore=False)
#         (loss_bbox): GIoULoss()
#         (fc_cls): Linear(in_features=1024, out_features=2, bias=True)
#         (fc_reg): Linear(in_features=1024, out_features=4, bias=True)
#         (shared_convs): ModuleList(
#           (0): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (2): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (3): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#         )
#         (shared_fcs): ModuleList(
#           (0): Linear(in_features=12544, out_features=1024, bias=True)
#         )
#         (cls_convs): ModuleList()
#         (cls_fcs): ModuleList()
#         (reg_convs): ModuleList()
#         (reg_fcs): ModuleList()
#         (relu): ReLU(inplace=True)
#       )
#       init_cfg=[{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
#       (2): ConvFCBBoxHead(
#         (loss_cls): CrossEntropyLoss(avg_non_ignore=False)
#         (loss_bbox): GIoULoss()
#         (fc_cls): Linear(in_features=1024, out_features=2, bias=True)
#         (fc_reg): Linear(in_features=1024, out_features=4, bias=True)
#         (shared_convs): ModuleList(
#           (0): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (1): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (2): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#           (3): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn): _BatchNormXd(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (activate): ReLU(inplace=True)
#           )
#         )
#         (shared_fcs): ModuleList(
#           (0): Linear(in_features=12544, out_features=1024, bias=True)
#         )
#         (cls_convs): ModuleList()
#         (cls_fcs): ModuleList()
#         (reg_convs): ModuleList()
#         (reg_fcs): ModuleList()
#         (relu): ReLU(inplace=True)
#       )
#       init_cfg=[{'type': 'Normal', 'std': 0.01, 'override': {'name': 'fc_cls'}}, {'type': 'Normal', 'std': 0.001, 'override': {'name': 'fc_reg'}}, {'type': 'Xavier', 'distribution': 'uniform', 'override': [{'name': 'shared_fcs'}, {'name': 'cls_fcs'}, {'name': 'reg_fcs'}]}]
#     )
#     (mask_head): ModuleList(
#       (0): FCNMaskHead(
#         (loss_mask): CrossEntropyLoss(avg_non_ignore=False)
#         (convs): ModuleList(
#           (0): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (activate): ReLU(inplace=True)
#           )
#           (1): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (activate): ReLU(inplace=True)
#           )
#           (2): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (activate): ReLU(inplace=True)
#           )
#           (3): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (activate): ReLU(inplace=True)
#           )
#         )
#         (upsample): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#         (conv_logits): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (1): FCNMaskHead(
#         (loss_mask): CrossEntropyLoss(avg_non_ignore=False)
#         (convs): ModuleList(
#           (0): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (activate): ReLU(inplace=True)
#           )
#           (1): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (activate): ReLU(inplace=True)
#           )
#           (2): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (activate): ReLU(inplace=True)
#           )
#           (3): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (activate): ReLU(inplace=True)
#           )
#         )
#         (upsample): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#         (conv_logits): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (2): FCNMaskHead(
#         (loss_mask): CrossEntropyLoss(avg_non_ignore=False)
#         (convs): ModuleList(
#           (0): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (activate): ReLU(inplace=True)
#           )
#           (1): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (activate): ReLU(inplace=True)
#           )
#           (2): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (activate): ReLU(inplace=True)
#           )
#           (3): ConvModule(
#             (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (activate): ReLU(inplace=True)
#           )
#         )
#         (upsample): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#         (conv_logits): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (mask_roi_extractor): ModuleList(
#       (0): SingleRoIExtractor(
#         (roi_layers): ModuleList(
#           (0): RoIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (1): RoIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (2): RoIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (3): RoIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         )
#       )
#       (1): SingleRoIExtractor(
#         (roi_layers): ModuleList(
#           (0): RoIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (1): RoIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (2): RoIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (3): RoIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         )
#       )
#       (2): SingleRoIExtractor(
#         (roi_layers): ModuleList(
#           (0): RoIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (1): RoIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (2): RoIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#           (3): RoIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, pool_mode=avg, aligned=True, use_torchvision=False)
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# # Val

# %%
runs = []
for size in [640, 768, 896, 1024, 1152, 1280, 1408, 1536]:
    print(f"[{size}]")
    cfg.load_from = f"{CFG.general.output_path}/{CFG.general.save_name}/epoch_1.pth"
    #cfg.load_from = f"{CFG.general.output_path}/{CFG.general.save_name}/iter_10000.pth"
    cfg.test_pipeline = [
            dict(type="LoadImageFromFile", backend_args=None),
            dict(type="Resize", scale=(size, size), keep_ratio=True),
            dict(type="LoadAnnotations", with_bbox=True, with_mask=True),
            dict(
                type="PackDetInputs",
                meta_keys=("img_id", "img_path", "ori_shape", "img_shape", "scale_factor"))
        ]
    cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
    runner = Runner.from_cfg(cfg)
    runs.append(runner)
# Out:
# [640]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [13], line 14
#       5 #cfg.load_from = f"{CFG.general.output_path}/{CFG.general.save_name}/iter_10000.pth"
#       6 cfg.test_pipeline = [
#       7         dict(type="LoadImageFromFile", backend_args=None),
#       8         dict(type="Resize", scale=(size, size), keep_ratio=True),
#    (...)
#      12             meta_keys=("img_id", "img_path", "ori_shape", "img_shape", "scale_factor"))
#      13     ]
# ---> 14 cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
#      15 runner = Runner.from_cfg(cfg)
#      16 runs.append(runner)
#
# AttributeError: 'NoneType' object has no attribute 'dataset'

# %%
for run_, size in zip(runs, [640, 768, 896, 1024, 1152, 1280, 1408, 1536]):
    print(f"[{size}]")
    run_.val()

# %%
# 640 -> 406, 768 -> 422, 896 -> 428, 1024 -> 440, 1152 -> 433, 1280 -> 439, 1408 -> 431, 1536 -> 420

# resnext
# 640 -> 410, 768 -> 435, 896 -> 441, 1024 -> 440, 1152 -> 441, 1280 -> 443, 1408 -> 432, 1536 -> 429

# convnext tiny
# 640 -> 435, 768 -> 449, 896 -> 454, 1024 -> 455, 1152 -> 456, 1280 -> 453, 1408 -> 450, 1536 -> 443

# %%
img = mmcv.imread(f"{CFG.general.input_path}/train/0006ff2aa7cd.tif", channel_order="rgb")
checkpoint_file = f"{CFG.general.output_path}/{CFG.general.save_name}/epoch_1.pth"
model = init_detector(cfg, checkpoint_file)
new_result = inference_detector(model, img)
print(new_result)

# %%
# get built visualizer
visualizer_now = Visualizer.get_current_instance()
# the dataset_meta is loaded from the checkpoint and
# then pass to the model in init_detector
visualizer_now.dataset_meta = model.dataset_meta
# show the results
visualizer_now.add_datasample(
    "new_result",
    img,
    data_sample=new_result,
    draw_gt=False,
    wait_time=0,
    out_file=None,
    pred_score_thr=0.5
)
visualizer_now.show()
