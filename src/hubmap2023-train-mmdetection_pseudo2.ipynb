# %% [markdown]
# # Import

# %%
import mmdet
import mmcv
import mmengine
from mmengine import Config
from mmengine.runner import set_random_seed
#from mmdet.datasets import build_dataset
#from mmdet.models import build_detector
from mmengine.runner import Runner
from mmdet.apis import init_detector, inference_detector
from mmengine.visualization import Visualizer

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
import json

import warnings
warnings.filterwarnings('ignore') #Ignore "future" warnings and Data-Frame-Slicing warnings.

from sklearn.model_selection import KFold, StratifiedKFold
from pytorch_lightning import seed_everything

# %% [markdown]
# # Config

# %%
class CFG:
    class general:
        #project_name = "HuBMAP2023"
        input_path = "../data/input"
        output_path = "../data/output"
        save_name = "convnext_fold_pseudo2_095_lr-6_10000"
        seed = 0
        cv = True
        #wandb_desabled = True
        n_splits = 5
        fold = [0] # list (0-idx start) or null. Set one element list, hold-out mode.

# %% [markdown]
# # Main

# %% [markdown]
# ### Read data

# %%
tile_meta = pd.read_csv(f"{CFG.general.input_path}/tile_meta.csv")
polygons = pd.read_json(f"{CFG.general.input_path}/polygons.jsonl", lines=True)
train = pd.merge(polygons, tile_meta, on="id", how="left")
print(len(train))
# Out:
# 1633

# %%
not_used = train[(train["source_wsi"]==1) & (train["dataset"]!=1)].reset_index(drop=True)
print(len(not_used))
# Out:
# 237

# %%
train_not1 = train[train["dataset"]!=1].reset_index(drop=True)
print(len(train_not1))
# Out:
# 1211

# %%
train = train[train["dataset"]==1].reset_index(drop=True) # using only dataset1
print(len(train))
# Out:
# 422

# %%
valid_cv = train[(train["source_wsi"]==1) & (train["dataset"]==1)].reset_index(drop=True)
train_cv = train[(train["source_wsi"]!=1)].reset_index(drop=True)

# %%
with open(f"{CFG.general.input_path}/coco_annotations_all.json") as f:
    coco_json = json.load(f)

# %%
coco_info = pd.DataFrame(coco_json["info"])
coco_licenses = pd.DataFrame(coco_json["licenses"])
coco_categories = pd.DataFrame(coco_json["categories"])
coco_images = pd.DataFrame(coco_json["images"])
coco_annotations = pd.DataFrame(coco_json["annotations"])

# %%
with open(f"{CFG.general.input_path}/val_change/coco_annotations_pseudo2_c095_convnext.json") as f:
    coco_pseudo_json = json.load(f)

# %%
coco_info_pseudo = pd.DataFrame(coco_pseudo_json["info"])
coco_licenses_pseudo = pd.DataFrame(coco_pseudo_json["licenses"])
coco_categories_pseudo = pd.DataFrame(coco_pseudo_json["categories"])
coco_images_pseudo = pd.DataFrame(coco_pseudo_json["images"])
coco_annotations_pseudo = pd.DataFrame(coco_pseudo_json["annotations"])

# %%
if CFG.general.cv:
    for fold_n in CFG.general.fold:
        print(f"fold{fold_n}: create json")
        #train_indices, valid_indices = list(kf.split(train))[fold_n]
        #train_cv = train.iloc[train_indices].reset_index(drop=True)
        #valid_cv = train.iloc[valid_indices].reset_index(drop=True)
        
        # dataset1以外も訓練に使うかどうか？
        #train_cv = pd.concat([train_cv, train_not1]).reset_index(drop=True)

        coco_images_train = coco_images[coco_images["id"].isin(train_cv["id"])].reset_index(drop=True)
        coco_images_valid = coco_images[coco_images["id"].isin(valid_cv["id"])].reset_index(drop=True)
        
        coco_annotations_train = coco_annotations[coco_annotations["image_id"].isin(train_cv["id"])].reset_index(drop=True)
        coco_annotations_valid = coco_annotations[coco_annotations["image_id"].isin(valid_cv["id"])].reset_index(drop=True)
        
        # pseudo labelからsource_wsi1を除く
        coco_images_pseudo = coco_images_pseudo[~coco_images_pseudo["id"].isin(not_used["id"])].reset_index(drop=True)
        coco_annotations_pseudo = coco_annotations_pseudo[~coco_annotations_pseudo["image_id"].isin(not_used["id"])].reset_index(drop=True)
        
        # pseudo label データ使うかどうか
        coco_images_train = pd.concat([coco_images_train, coco_images_pseudo]).reset_index(drop=True)
        coco_annotations_train = pd.concat([coco_annotations_train, coco_annotations_pseudo]).reset_index(drop=True)
        
        # pseudo label only
        #coco_images_train = coco_images_pseudo
        #coco_annotations_train = coco_annotations_pseudo
        
        # bloodだけにするかどうか
        coco_annotations_train = coco_annotations_train[coco_annotations_train["category_id"]==2].reset_index(drop=True)
        coco_annotations_valid = coco_annotations_valid[coco_annotations_valid["category_id"]==2].reset_index(drop=True)
        
        # unsureを除くかどうか
        #coco_annotations_train = coco_annotations_train[coco_annotations_train["category_id"]!=3].reset_index(drop=True)
        #coco_annotations_valid = coco_annotations_valid[coco_annotations_valid["category_id"]!=3].reset_index(drop=True)
        
        # glomerulusを除くかどうか
        #coco_annotations_train = coco_annotations_train[coco_annotations_train["category_id"]!=1].reset_index(drop=True)
        #coco_annotations_valid = coco_annotations_valid[coco_annotations_valid["category_id"]!=1].reset_index(drop=True)        
        
        # unsureをbloodにするかどうか
        #coco_annotations_train.loc[coco_annotations_train["category_id"]==3, "category_id"] = 2
        #coco_annotations_valid.loc[coco_annotations_valid["category_id"]==3, "category_id"] = 2
        
        coco_annotations_train["id"] = coco_annotations_train.index + 1
        coco_annotations_valid["id"] = coco_annotations_valid.index + 1

        coco_json_train = coco_json.copy()
        coco_json_valid = coco_json.copy()

        coco_json_train["categories"] = [coco_categories.iloc[1].to_dict()]
        coco_json_valid["categories"] = [coco_categories.iloc[1].to_dict()]
        #coco_json_train["categories"] = coco_categories.iloc[:2].to_dict(orient="records")
        #coco_json_valid["categories"] = coco_categories.iloc[:2].to_dict(orient="records")
        
        coco_json_train["images"] = coco_images_train.to_dict(orient="records")
        coco_json_train["annotations"] = coco_annotations_train.to_dict(orient="records")
        coco_json_valid["images"] = coco_images_valid.to_dict(orient="records")
        coco_json_valid["annotations"] = coco_annotations_valid.to_dict(orient="records")

        output_file_path = f"{CFG.general.input_path}/coco_annotations_train_fold{fold_n}.json"
        with open(output_file_path, "w", encoding="utf-8") as output_file:
            json.dump(coco_json_train, output_file, ensure_ascii=True, indent=4)

        output_file_path = f"{CFG.general.input_path}/coco_annotations_valid_fold{fold_n}.json"
        with open(output_file_path, "w", encoding="utf-8") as output_file:
            json.dump(coco_json_valid, output_file, ensure_ascii=True, indent=4)
            
        print(f"train annos: {len(coco_annotations_train)}, images: {len(coco_images_train)}")
        print(f"valid annos: {len(coco_annotations_valid)}, images: {len(coco_images_valid)}")
else:
    pass
    """
    print(f"fold all: create json")
    coco_annotations_train = coco_annotations_train[coco_annotations_train["category_id"]==2].reset_index(drop=True)
    coco_annotations_valid = coco_annotations_valid[coco_annotations_valid["category_id"]==2].reset_index(drop=True)
    coco_annotations_train["id"] = coco_annotations_train.index + 1
    coco_annotations_valid["id"] = coco_annotations_valid.index + 1
    
    coco_json_train = coco_json.copy()
    coco_json_valid = coco_json.copy()
    
    coco_json_train["categories"] = [coco_categories.iloc[1].to_dict()]
    coco_json_train["images"] = coco_images_train.to_dict(orient="records")
    coco_json_train["annotations"] = coco_annotations_train.to_dict(orient="records")
    coco_json_valid["categories"] = [coco_categories.iloc[1].to_dict()]
    coco_json_valid["images"] = coco_images_valid.to_dict(orient="records")
    coco_json_valid["annotations"] = coco_annotations_valid.to_dict(orient="records")
    
    output_file_path = f"coco_annotations_train_fold_all.json"
    with open(output_file_path, "w", encoding="utf-8") as output_file:
        json.dump(coco_json_train, output_file, ensure_ascii=True, indent=4)

    output_file_path = f"coco_annotations_valid_fold_all.json"
    with open(output_file_path, "w", encoding="utf-8") as output_file:
        json.dump(coco_json_valid, output_file, ensure_ascii=True, indent=4)
    """
# Out:
# fold0: create json
# train annos: 67555, images: 6526
# valid annos: 1182, images: 270

# %%
backbone = "convnext"
if backbone == "convnext":
    cfg = Config.fromfile("../mmdetection/configs/convnext/cascade-mask-rcnn_convnext-t-p4-w7_fpn_4conv1fc-giou_amp-ms-crop-3x_coco.py")
    #cfg.work_dir = ""
    #Runner.from_cfg(cfg)
    
    # cfg dataset
    cfg.metainfo = {
        #"classes": ("glomerulus", "blood_vessel", )
        "classes": ("blood_vessel", )
    }
    cfg.train_pipeline = [
            dict(type="LoadImageFromFile", backend_args=None),
            dict(type="LoadAnnotations", with_bbox=True, with_mask=True, poly2mask=True),
            dict(
                type="RandomChoiceResize",
                scales=[(640, 640), (768, 768), (896, 896), (1024, 1024), (1152, 1152), (1280, 1280), (1408, 1408), (1536, 1536)],
                keep_ratio=True),
            dict(
                #type="RandomFlip", direction=["horizontal", "vertical"], prob=[0.5, 0.5],
                type="RandomFlip",prob=0.0
                ),
            dict(type="PackDetInputs")
        ]
    cfg.train_dataloader.dataset.pipeline = cfg.train_pipeline
    cfg.test_pipeline = [
            dict(type="LoadImageFromFile", backend_args=None),
            dict(type="Resize", scale=(1024, 1024), keep_ratio=True),
            dict(type="LoadAnnotations", with_bbox=True, with_mask=True),
            dict(
                type="PackDetInputs",
                meta_keys=("img_id", "img_path", "ori_shape", "img_shape", "scale_factor"))
        ]
    cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
    cfg.data_root = f"{CFG.general.input_path}"
    cfg.train_dataloader.dataset.ann_file = f"coco_annotations_train_fold{fold_n}.json"
    cfg.train_dataloader.dataset.data_root = cfg.data_root
    cfg.train_dataloader.dataset.data_prefix.img = "train"
    cfg.train_dataloader.dataset.metainfo = cfg.metainfo
    cfg.val_dataloader.dataset.ann_file = f"coco_annotations_valid_fold{fold_n}.json"
    cfg.val_dataloader.dataset.data_root = cfg.data_root
    cfg.val_dataloader.dataset.data_prefix.img = "train"
    cfg.val_dataloader.dataset.metainfo = cfg.metainfo
    cfg.test_dataloader = cfg.val_dataloader
    cfg.val_evaluator.ann_file = f"{CFG.general.input_path}/coco_annotations_valid_fold{fold_n}.json"
    cfg.val_evaluator.metric = "segm"
    cfg.test_evaluator = cfg.val_evaluator

    # classes
    cfg.model.roi_head.bbox_head[0].num_classes = 1
    cfg.model.roi_head.bbox_head[1].num_classes = 1
    cfg.model.roi_head.bbox_head[2].num_classes = 1
    cfg.model.roi_head.mask_head.num_classes = 1

    # pretrained weight
    #cfg.load_from = "/notebooks/data/output/third_fold/convnext_fold_3rd_dataset1_only_retry/epoch_1.pth"
    cfg.load_from = "/notebooks/data/output/pseudo_fold/exp101_convnext_validchange_pseudo05_ens/epoch_1.pth"
    
    # Set up working dir to save files and logs
    cfg.work_dir = f"{CFG.general.output_path}/{CFG.general.save_name}"

    # training configs, learning rate, optimizer
    max_iter = 10000
    cfg.train_cfg = dict(type="IterBasedTrainLoop", max_iters=max_iter, val_interval=500)
    cfg.train_dataloader.sampler = dict(type="InfiniteSampler", shuffle=True)
    cfg.log_processor = dict(by_epoch=False)
    cfg.optim_wrapper.type = "AmpOptimWrapper"
    #cfg.optim_wrapper.optimizer = dict(type="SGD", lr=0.01, momentum=0.9, weight_decay=1e-05)
    cfg.optim_wrapper.optimizer = dict(type="AdamW", lr=0.000002, betas=(0.9, 0.999,), weight_decay=0.05)
    cfg.param_scheduler = [
            dict(
                type="LinearLR", start_factor=1.0e-3, by_epoch=False, begin=0, end=int(max_iter*0.1)),
            dict(
                type="CosineAnnealingLR",
                T_max=max_iter-int(max_iter*0.1),
                by_epoch=False,
                begin=int(max_iter*0.1),
                end=max_iter)
        ]

    # logger
    cfg.default_hooks.checkpoint.interval = 0
    cfg.default_hooks.logger.interval = 100

    # Set seed thus the results are more reproducible
    set_random_seed(CFG.general.seed, deterministic=False)
    
elif backbone == "resnet":
    #cfg = Config.fromfile("../mmdetection/configs/cascade_rcnn/cascade-mask-rcnn_r50_fpn_ms-3x_coco.py")
    cfg = Config.fromfile("../mmdetection/configs/cascade_rcnn/cascade-mask-rcnn_x101-64x4d_fpn_ms-3x_coco.py")
    
    # cfg dataset
    cfg.metainfo = {
        "classes": ("blood_vessel", )
    }
    cfg.train_pipeline = [
            dict(type="LoadImageFromFile", backend_args=None),
            dict(type="LoadAnnotations", with_bbox=True, with_mask=True, poly2mask=True),
            dict(
                type="RandomChoiceResize",
                scales=[(640, 640), (768, 768), (896, 896), (1024, 1024), (1152, 1152), (1280, 1280), (1408, 1408), (1536, 1536)],
                keep_ratio=True),
            dict(
                type="RandomFlip",
            prob=0.0),
            dict(type="PackDetInputs")
        ]
    cfg.train_dataloader.dataset.dataset.pipeline = cfg.train_pipeline
    cfg.test_pipeline = [
            dict(type="LoadImageFromFile", backend_args=None),
            dict(type="Resize", scale=(1024, 1024), keep_ratio=True),
            dict(type="LoadAnnotations", with_bbox=True, with_mask=True),
            dict(
                type="PackDetInputs",
                meta_keys=("img_id", "img_path", "ori_shape", "img_shape", "scale_factor"))
        ]
    cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
    cfg.data_root = f"{CFG.general.input_path}"
    cfg.train_dataloader.dataset.dataset.ann_file = f"coco_annotations_train_fold{fold_n}.json"
    cfg.train_dataloader.dataset.dataset.data_root = cfg.data_root
    cfg.train_dataloader.dataset.dataset.data_prefix.img = "train"
    cfg.train_dataloader.dataset.dataset.metainfo = cfg.metainfo
    cfg.val_dataloader.dataset.ann_file = f"coco_annotations_valid_fold{fold_n}.json"
    cfg.val_dataloader.dataset.data_root = cfg.data_root
    cfg.val_dataloader.dataset.data_prefix.img = "train"
    cfg.val_dataloader.dataset.metainfo = cfg.metainfo
    cfg.test_dataloader = cfg.val_dataloader
    cfg.val_evaluator.ann_file = f"{CFG.general.input_path}/coco_annotations_valid_fold{fold_n}.json"
    cfg.val_evaluator.metric = "segm"
    cfg.test_evaluator = cfg.val_evaluator

    # classes
    cfg.model.roi_head.bbox_head[0].num_classes = 1
    cfg.model.roi_head.bbox_head[1].num_classes = 1
    cfg.model.roi_head.bbox_head[2].num_classes = 1
    cfg.model.roi_head.mask_head.num_classes = 1

    # pretrained weight
    #cfg.load_from = "../data/pretrained_weight/cascade_mask_rcnn_r50_fpn_mstrain_3x_coco_20210628_164719-5bdc3824.pth"
    cfg.load_from = "/notebooks/data/output/base_fold/resnext_valid_change/epoch_1.pth"
    #cfg.load_from = "../data/pretrained_weight/cascade_mask_rcnn_x101_64x4d_fpn_mstrain_3x_coco_20210719_210311-d3e64ba0.pth"
    #cfg.load_from = "/notebooks/data/output/base_fold/resnet_valid_change/epoch_1.pth"

    # Set up working dir to save files and logs
    cfg.work_dir = f"{CFG.general.output_path}/{CFG.general.save_name}"

    # training configs, learning rate, optimizer
    cfg.train_dataloader.dataset.times = 1
    max_iter = 10000
    cfg.train_cfg = dict(type="IterBasedTrainLoop", max_iters=max_iter, val_interval=500)
    cfg.train_dataloader.sampler = dict(type="InfiniteSampler", shuffle=True)
    cfg.log_processor = dict(by_epoch=False)
    cfg.optim_wrapper.type = "AmpOptimWrapper"
    cfg.optim_wrapper.optimizer.type = "SGD"
    cfg.optim_wrapper.optimizer.lr = 1.0e-2
    cfg.optim_wrapper.optimizer.weight_decay = 1.0e-5
    cfg.param_scheduler = [
            dict(
                type="LinearLR", start_factor=1.0e-3, by_epoch=False, begin=0, end=int(max_iter*0.1)),
            dict(
                type="CosineAnnealingLR",
                T_max=max_iter-int(max_iter*0.1),
                by_epoch=False,
                begin=int(max_iter*0.1),
                end=max_iter)
        ]

    # logger
    cfg.default_hooks.checkpoint.interval = 0
    cfg.default_hooks.logger.interval = 100

    # Set seed thus the results are more reproducible
    set_random_seed(CFG.general.seed, deterministic=False)

elif backbone == "mask2former":
    cfg = Config.fromfile("../mmdetection/configs/mask2former/mask2former_swin-t-p4-w7-224_8xb2-lsj-50e_coco.py")
    #cfg.work_dir = "../../"
    #Runner.from_cfg(cfg)
    
    # cfg dataset
    cfg.metainfo = {
        "classes": ("blood_vessel", )
    }
    cfg.train_pipeline[2] = dict(type="RandomFlip", prob=0.0)
    cfg.train_dataloader.dataset.pipeline = cfg.train_pipeline
    cfg.test_pipeline[1] = dict(type="Resize", scale=(1024, 1024), keep_ratio=True)
    cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
    cfg.data_root = f"{CFG.general.input_path}"
    cfg.train_dataloader.dataset.ann_file = f"coco_annotations_train_fold{fold_n}.json"
    cfg.train_dataloader.dataset.data_root = cfg.data_root
    cfg.train_dataloader.dataset.data_prefix.img = "train"
    cfg.train_dataloader.dataset.metainfo = cfg.metainfo
    cfg.val_dataloader.dataset.ann_file = f"coco_annotations_valid_fold{fold_n}.json"
    cfg.val_dataloader.dataset.data_root = cfg.data_root
    cfg.val_dataloader.dataset.data_prefix.img = "train"
    cfg.val_dataloader.dataset.metainfo = cfg.metainfo
    cfg.test_dataloader = cfg.val_dataloader
    cfg.val_evaluator.ann_file = f"{CFG.general.input_path}/coco_annotations_valid_fold{fold_n}.json"
    cfg.val_evaluator.metric = "segm"
    cfg.test_evaluator = cfg.val_evaluator

    # classes
    cfg.num_things_classes = 1
    cfg.num_classes = 1
    cfg.model.panoptic_head.num_things_classes = cfg.num_things_classes
    cfg.model.panoptic_head.num_stuff_classes = cfg.num_stuff_classes
    cfg.model.panoptic_fusion_head.num_things_classes = cfg.num_things_classes
    cfg.model.panoptic_fusion_head.num_stuff_classes = cfg.num_stuff_classes
    cfg.model.panoptic_head.loss_cls["class_weight"] = [1.0] * cfg.num_classes + [0.1]

    # pretrained weight
    cfg.load_from = "../data/pretrained_weight/mask2former_swin-t-p4-w7-224_8xb2-lsj-50e_coco_20220508_091649-01b0f990.pth"

    # Set up working dir to save files and logs
    cfg.work_dir = f"{CFG.general.output_path}/{CFG.general.save_name}"

    # training configs, learning rate, optimizer
    max_iter = 10000
    cfg.train_cfg = dict(type="IterBasedTrainLoop", max_iters=max_iter, val_interval=500)
    cfg.train_dataloader.sampler = dict(type="InfiniteSampler", shuffle=True)
    cfg.log_processor = dict(by_epoch=False)
    cfg.optim_wrapper.type = "AmpOptimWrapper"
    #cfg.optim_wrapper.optimizer = dict(type="SGD", lr=0.01, momentum=0.9, weight_decay=1e-05)
    cfg.param_scheduler = [
            dict(
                type="LinearLR", start_factor=1.0e-3, by_epoch=False, begin=0, end=int(max_iter*0.1)),
            dict(
                type="CosineAnnealingLR",
                T_max=max_iter-int(max_iter*0.1),
                by_epoch=False,
                begin=int(max_iter*0.1),
                end=max_iter)
        ]

    # logger
    cfg.default_hooks.checkpoint.interval = 0
    cfg.default_hooks.logger.interval = 100

    # Set seed thus the results are more reproducible
    set_random_seed(CFG.general.seed, deterministic=False)

# %%
runner = Runner.from_cfg(cfg)
# Out:
# 07/31 13:18:33 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.9.16 (main, Dec  7 2022, 01:11:51) [GCC 9.4.0]
#     CUDA available: True
#     numpy_random_seed: 209652396
#     GPU 0: NVIDIA RTX A6000
#     CUDA_HOME: /usr/local/cuda-11.6
#     NVCC: Cuda compilation tools, release 11.6, V11.6.124
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 9.4.0-1ubuntu1~20.04.1) 9.4.0
#     PyTorch: 1.12.1+cu116
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v2.6.0 (Git Hash 52b5f107dd9cf10910aaa19cb47f3abf9b349815)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.6
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.3.2  (built against CUDA 11.5)
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.6, CUDNN_VERSION=8.3.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -fabi-version=11 -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -DEDGE_PROFILER_USE_KINETO -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.12.1, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=OFF, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.13.1+cu116
#     OpenCV: 4.6.0
#     MMEngine: 0.8.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 209652396
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 07/31 13:18:34 - mmengine - INFO - Config:
# auto_scale_lr = dict(base_batch_size=16, enable=False)
# backend_args = None
# checkpoint_file = 'https://download.openmmlab.com/mmclassification/v0/convnext/downstream/convnext-tiny_3rdparty_32xb128-noema_in1k_20220301-795e9634.pth'
# custom_imports = dict(
#     allow_failed_imports=False, imports=[
#         'mmpretrain.models',
#     ])
# data_root = '../data/input'
# dataset_type = 'CocoDataset'
# default_hooks = dict(
#     checkpoint=dict(interval=0, type='CheckpointHook'),
#     logger=dict(interval=100, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     timer=dict(type='IterTimerHook'),
#     visualization=dict(type='DetVisualizationHook'))
# default_scope = 'mmdet'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# load_from = '/notebooks/data/output/pseudo_fold/exp101_convnext_validchange_pseudo05_ens/epoch_1.pth'
# log_level = 'INFO'
# log_processor = dict(by_epoch=False)
# max_epochs = 36
# metainfo = dict(classes=('blood_vessel', ))
# model = dict(
#     backbone=dict(
#         arch='tiny',
#         drop_path_rate=0.4,
#         gap_before_final_norm=False,
#         init_cfg=dict(
#             checkpoint=
#             'https://download.openmmlab.com/mmclassification/v0/convnext/downstream/convnext-tiny_3rdparty_32xb128-noema_in1k_20220301-795e9634.pth',
#             prefix='backbone.',
#             type='Pretrained'),
#         layer_scale_init_value=1.0,
#         out_indices=[
#             0,
#             1,
#             2,
#             3,
#         ],
#         type='mmpretrain.ConvNeXt'),
#     data_preprocessor=dict(
#         bgr_to_rgb=True,
#         mean=[
#             123.675,
#             116.28,
#             103.53,
#         ],
#         pad_mask=True,
#         pad_size_divisor=32,
#         std=[
#             58.395,
#             57.12,
#             57.375,
#         ],
#         type='DetDataPreprocessor'),
#     neck=dict(
#         in_channels=[
#             96,
#             192,
#             384,
#             768,
#         ],
#         num_outs=5,
#         out_channels=256,
#         type='FPN'),
#     roi_head=dict(
#         bbox_head=[
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.1,
#                         0.1,
#                         0.2,
#                         0.2,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 conv_out_channels=256,
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(loss_weight=10.0, type='GIoULoss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 norm_cfg=dict(requires_grad=True, type='SyncBN'),
#                 num_classes=1,
#                 num_shared_convs=4,
#                 num_shared_fcs=1,
#                 reg_class_agnostic=False,
#                 reg_decoded_bbox=True,
#                 roi_feat_size=7,
#                 type='ConvFCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.05,
#                         0.05,
#                         0.1,
#                         0.1,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 conv_out_channels=256,
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(loss_weight=10.0, type='GIoULoss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 norm_cfg=dict(requires_grad=True, type='SyncBN'),
#                 num_classes=1,
#                 num_shared_convs=4,
#                 num_shared_fcs=1,
#                 reg_class_agnostic=False,
#                 reg_decoded_bbox=True,
#                 roi_feat_size=7,
#                 type='ConvFCBBoxHead'),
#             dict(
#                 bbox_coder=dict(
#                     target_means=[
#                         0.0,
#                         0.0,
#                         0.0,
#                         0.0,
#                     ],
#                     target_stds=[
#                         0.033,
#                         0.033,
#                         0.067,
#                         0.067,
#                     ],
#                     type='DeltaXYWHBBoxCoder'),
#                 conv_out_channels=256,
#                 fc_out_channels=1024,
#                 in_channels=256,
#                 loss_bbox=dict(loss_weight=10.0, type='GIoULoss'),
#                 loss_cls=dict(
#                     loss_weight=1.0,
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False),
#                 norm_cfg=dict(requires_grad=True, type='SyncBN'),
#                 num_classes=1,
#                 num_shared_convs=4,
#                 num_shared_fcs=1,
#                 reg_class_agnostic=False,
#                 reg_decoded_bbox=True,
#                 roi_feat_size=7,
#                 type='ConvFCBBoxHead'),
#         ],
#         bbox_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=7, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         mask_head=dict(
#             conv_out_channels=256,
#             in_channels=256,
#             loss_mask=dict(
#                 loss_weight=1.0, type='CrossEntropyLoss', use_mask=True),
#             num_classes=1,
#             num_convs=4,
#             type='FCNMaskHead'),
#         mask_roi_extractor=dict(
#             featmap_strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#             ],
#             out_channels=256,
#             roi_layer=dict(output_size=14, sampling_ratio=0, type='RoIAlign'),
#             type='SingleRoIExtractor'),
#         num_stages=3,
#         stage_loss_weights=[
#             1,
#             0.5,
#             0.25,
#         ],
#         type='CascadeRoIHead'),
#     rpn_head=dict(
#         anchor_generator=dict(
#             ratios=[
#                 0.5,
#                 1.0,
#                 2.0,
#             ],
#             scales=[
#                 8,
#             ],
#             strides=[
#                 4,
#                 8,
#                 16,
#                 32,
#                 64,
#             ],
#             type='AnchorGenerator'),
#         bbox_coder=dict(
#             target_means=[
#                 0.0,
#                 0.0,
#                 0.0,
#                 0.0,
#             ],
#             target_stds=[
#                 1.0,
#                 1.0,
#                 1.0,
#                 1.0,
#             ],
#             type='DeltaXYWHBBoxCoder'),
#         feat_channels=256,
#         in_channels=256,
#         loss_bbox=dict(
#             beta=0.1111111111111111, loss_weight=1.0, type='SmoothL1Loss'),
#         loss_cls=dict(
#             loss_weight=1.0, type='CrossEntropyLoss', use_sigmoid=True),
#         type='RPNHead'),
#     test_cfg=dict(
#         rcnn=dict(
#             mask_thr_binary=0.5,
#             max_per_img=100,
#             nms=dict(iou_threshold=0.5, type='nms'),
#             score_thr=0.05),
#         rpn=dict(
#             max_per_img=1000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=1000)),
#     train_cfg=dict(
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.5,
#                     neg_iou_thr=0.5,
#                     pos_iou_thr=0.5,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.6,
#                     neg_iou_thr=0.6,
#                     pos_iou_thr=0.6,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#             dict(
#                 assigner=dict(
#                     ignore_iof_thr=-1,
#                     match_low_quality=False,
#                     min_pos_iou=0.7,
#                     neg_iou_thr=0.7,
#                     pos_iou_thr=0.7,
#                     type='MaxIoUAssigner'),
#                 debug=False,
#                 mask_size=28,
#                 pos_weight=-1,
#                 sampler=dict(
#                     add_gt_as_proposals=True,
#                     neg_pos_ub=-1,
#                     num=512,
#                     pos_fraction=0.25,
#                     type='RandomSampler')),
#         ],
#         rpn=dict(
#             allowed_border=0,
#             assigner=dict(
#                 ignore_iof_thr=-1,
#                 match_low_quality=True,
#                 min_pos_iou=0.3,
#                 neg_iou_thr=0.3,
#                 pos_iou_thr=0.7,
#                 type='MaxIoUAssigner'),
#             debug=False,
#             pos_weight=-1,
#             sampler=dict(
#                 add_gt_as_proposals=False,
#                 neg_pos_ub=-1,
#                 num=256,
#                 pos_fraction=0.5,
#                 type='RandomSampler')),
#         rpn_proposal=dict(
#             max_per_img=2000,
#             min_bbox_size=0,
#             nms=dict(iou_threshold=0.7, type='nms'),
#             nms_pre=2000)),
#     type='CascadeRCNN')
# optim_wrapper = dict(
#     constructor='LearningRateDecayOptimizerConstructor',
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=2e-06, type='AdamW', weight_decay=0.05),
#     paramwise_cfg=dict(decay_rate=0.7, decay_type='layer_wise', num_layers=6),
#     type='AmpOptimWrapper')
# param_scheduler = [
#     dict(
#         begin=0, by_epoch=False, end=1000, start_factor=0.001,
#         type='LinearLR'),
#     dict(
#         T_max=9000,
#         begin=1000,
#         by_epoch=False,
#         end=10000,
#         type='CosineAnnealingLR'),
# ]
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='coco_annotations_valid_fold0.json',
#         backend_args=None,
#         data_prefix=dict(img='train'),
#         data_root='../data/input',
#         metainfo=dict(classes=('blood_vessel', )),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1024,
#                 1024,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(
#     ann_file='../data/input/coco_annotations_valid_fold0.json',
#     backend_args=None,
#     format_only=False,
#     metric='segm',
#     type='CocoMetric')
# test_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(keep_ratio=True, scale=(
#         1024,
#         1024,
#     ), type='Resize'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(
#         meta_keys=(
#             'img_id',
#             'img_path',
#             'ori_shape',
#             'img_shape',
#             'scale_factor',
#         ),
#         type='PackDetInputs'),
# ]
# train_cfg = dict(max_iters=10000, type='IterBasedTrainLoop', val_interval=500)
# train_dataloader = dict(
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     batch_size=2,
#     dataset=dict(
#         ann_file='coco_annotations_train_fold0.json',
#         backend_args=None,
#         data_prefix=dict(img='train'),
#         data_root='../data/input',
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         metainfo=dict(classes=('blood_vessel', )),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(
#                 poly2mask=True,
#                 type='LoadAnnotations',
#                 with_bbox=True,
#                 with_mask=True),
#             dict(
#                 keep_ratio=True,
#                 scales=[
#                     (
#                         640,
#                         640,
#                     ),
#                     (
#                         768,
#                         768,
#                     ),
#                     (
#                         896,
#                         896,
#                     ),
#                     (
#                         1024,
#                         1024,
#                     ),
#                     (
#                         1152,
#                         1152,
#                     ),
#                     (
#                         1280,
#                         1280,
#                     ),
#                     (
#                         1408,
#                         1408,
#                     ),
#                     (
#                         1536,
#                         1536,
#                     ),
#                 ],
#                 type='RandomChoiceResize'),
#             dict(prob=0.0, type='RandomFlip'),
#             dict(type='PackDetInputs'),
#         ],
#         type='CocoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='InfiniteSampler'))
# train_pipeline = [
#     dict(backend_args=None, type='LoadImageFromFile'),
#     dict(
#         poly2mask=True, type='LoadAnnotations', with_bbox=True,
#         with_mask=True),
#     dict(
#         keep_ratio=True,
#         scales=[
#             (
#                 640,
#                 640,
#             ),
#             (
#                 768,
#                 768,
#             ),
#             (
#                 896,
#                 896,
#             ),
#             (
#                 1024,
#                 1024,
#             ),
#             (
#                 1152,
#                 1152,
#             ),
#             (
#                 1280,
#                 1280,
#             ),
#             (
#                 1408,
#                 1408,
#             ),
#             (
#                 1536,
#                 1536,
#             ),
#         ],
#         type='RandomChoiceResize'),
#     dict(prob=0.0, type='RandomFlip'),
#     dict(type='PackDetInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='coco_annotations_valid_fold0.json',
#         backend_args=None,
#         data_prefix=dict(img='train'),
#         data_root='../data/input',
#         metainfo=dict(classes=('blood_vessel', )),
#         pipeline=[
#             dict(backend_args=None, type='LoadImageFromFile'),
#             dict(keep_ratio=True, scale=(
#                 1024,
#                 1024,
#             ), type='Resize'),
#             dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#             dict(
#                 meta_keys=(
#                     'img_id',
#                     'img_path',
#                     'ori_shape',
#                     'img_shape',
#                     'scale_factor',
#                 ),
#                 type='PackDetInputs'),
#         ],
#         test_mode=True,
#         type='CocoDataset'),
#     drop_last=False,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(
#     ann_file='../data/input/coco_annotations_valid_fold0.json',
#     backend_args=None,
#     format_only=False,
#     metric='segm',
#     type='CocoMetric')
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     name='visualizer',
#     type='DetLocalVisualizer',
#     vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = '../data/output/convnext_fold_pseudo2_095_lr-6_10000'
#
# 07/31 13:18:36 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 07/31 13:18:36 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------

# %%
seed_everything(CFG.general.seed, workers=True)
runner.train()
# Out:
# Global seed set to 0
# loading annotations into memory...
# Done (t=1.48s)
# creating index...
# index created!
# 07/31 13:18:39 - mmengine - INFO - self.paramwise_cfg is {'decay_rate': 0.7, 'decay_type': 'layer_wise', 'num_layers': 6}
# 07/31 13:18:39 - mmengine - INFO - Build LearningRateDecayOptimizerConstructor  layer_wise 0.7 - 8
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.0.0.weight as id 0
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.0.0.bias as id 0
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.0.1.weight as id 0
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.0.1.bias as id 0
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.1.0.weight as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.1.0.bias as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.1.1.weight as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.1.1.bias as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.2.0.weight as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.2.0.bias as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.2.1.weight as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.2.1.bias as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.3.0.weight as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.3.0.bias as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.3.1.weight as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.downsample_layers.3.1.bias as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.0.gamma as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.0.depthwise_conv.weight as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.0.depthwise_conv.bias as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.0.norm.weight as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.0.norm.bias as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.0.pointwise_conv1.weight as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.0.pointwise_conv1.bias as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.0.pointwise_conv2.weight as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.0.pointwise_conv2.bias as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.1.gamma as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.1.depthwise_conv.weight as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.1.depthwise_conv.bias as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.1.norm.weight as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.1.norm.bias as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.1.pointwise_conv1.weight as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.1.pointwise_conv1.bias as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.1.pointwise_conv2.weight as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.1.pointwise_conv2.bias as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.2.gamma as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.2.depthwise_conv.weight as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.2.depthwise_conv.bias as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.2.norm.weight as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.2.norm.bias as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.2.pointwise_conv1.weight as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.2.pointwise_conv1.bias as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.2.pointwise_conv2.weight as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.0.2.pointwise_conv2.bias as id 1
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.0.gamma as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.0.depthwise_conv.weight as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.0.depthwise_conv.bias as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.0.norm.weight as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.0.norm.bias as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.0.pointwise_conv1.weight as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.0.pointwise_conv1.bias as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.0.pointwise_conv2.weight as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.0.pointwise_conv2.bias as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.1.gamma as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.1.depthwise_conv.weight as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.1.depthwise_conv.bias as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.1.norm.weight as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.1.norm.bias as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.1.pointwise_conv1.weight as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.1.pointwise_conv1.bias as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.1.pointwise_conv2.weight as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.1.pointwise_conv2.bias as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.2.gamma as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.2.depthwise_conv.weight as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.2.depthwise_conv.bias as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.2.norm.weight as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.2.norm.bias as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.2.pointwise_conv1.weight as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.2.pointwise_conv1.bias as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.2.pointwise_conv2.weight as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.1.2.pointwise_conv2.bias as id 2
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.0.gamma as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.0.depthwise_conv.weight as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.0.depthwise_conv.bias as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.0.norm.weight as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.0.norm.bias as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.0.pointwise_conv1.weight as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.0.pointwise_conv1.bias as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.0.pointwise_conv2.weight as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.0.pointwise_conv2.bias as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.1.gamma as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.1.depthwise_conv.weight as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.1.depthwise_conv.bias as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.1.norm.weight as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.1.norm.bias as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.1.pointwise_conv1.weight as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.1.pointwise_conv1.bias as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.1.pointwise_conv2.weight as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.1.pointwise_conv2.bias as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.2.gamma as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.2.depthwise_conv.weight as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.2.depthwise_conv.bias as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.2.norm.weight as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.2.norm.bias as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.2.pointwise_conv1.weight as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.2.pointwise_conv1.bias as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.2.pointwise_conv2.weight as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.2.pointwise_conv2.bias as id 3
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.3.gamma as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.3.depthwise_conv.weight as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.3.depthwise_conv.bias as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.3.norm.weight as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.3.norm.bias as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.3.pointwise_conv1.weight as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.3.pointwise_conv1.bias as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.3.pointwise_conv2.weight as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.3.pointwise_conv2.bias as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.4.gamma as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.4.depthwise_conv.weight as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.4.depthwise_conv.bias as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.4.norm.weight as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.4.norm.bias as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.4.pointwise_conv1.weight as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.4.pointwise_conv1.bias as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.4.pointwise_conv2.weight as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.4.pointwise_conv2.bias as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.5.gamma as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.5.depthwise_conv.weight as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.5.depthwise_conv.bias as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.5.norm.weight as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.5.norm.bias as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.5.pointwise_conv1.weight as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.5.pointwise_conv1.bias as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.5.pointwise_conv2.weight as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.5.pointwise_conv2.bias as id 4
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.6.gamma as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.6.depthwise_conv.weight as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.6.depthwise_conv.bias as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.6.norm.weight as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.6.norm.bias as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.6.pointwise_conv1.weight as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.6.pointwise_conv1.bias as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.6.pointwise_conv2.weight as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.6.pointwise_conv2.bias as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.7.gamma as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.7.depthwise_conv.weight as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.7.depthwise_conv.bias as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.7.norm.weight as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.7.norm.bias as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.7.pointwise_conv1.weight as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.7.pointwise_conv1.bias as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.7.pointwise_conv2.weight as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.7.pointwise_conv2.bias as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.8.gamma as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.8.depthwise_conv.weight as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.8.depthwise_conv.bias as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.8.norm.weight as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.8.norm.bias as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.8.pointwise_conv1.weight as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.8.pointwise_conv1.bias as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.8.pointwise_conv2.weight as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.2.8.pointwise_conv2.bias as id 5
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.0.gamma as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.0.depthwise_conv.weight as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.0.depthwise_conv.bias as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.0.norm.weight as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.0.norm.bias as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.0.pointwise_conv1.weight as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.0.pointwise_conv1.bias as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.0.pointwise_conv2.weight as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.0.pointwise_conv2.bias as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.1.gamma as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.1.depthwise_conv.weight as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.1.depthwise_conv.bias as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.1.norm.weight as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.1.norm.bias as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.1.pointwise_conv1.weight as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.1.pointwise_conv1.bias as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.1.pointwise_conv2.weight as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.1.pointwise_conv2.bias as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.2.gamma as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.2.depthwise_conv.weight as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.2.depthwise_conv.bias as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.2.norm.weight as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.2.norm.bias as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.2.pointwise_conv1.weight as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.2.pointwise_conv1.bias as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.2.pointwise_conv2.weight as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.stages.3.2.pointwise_conv2.bias as id 6
# 07/31 13:18:39 - mmengine - INFO - set param backbone.norm0.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param backbone.norm0.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param backbone.norm1.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param backbone.norm1.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param backbone.norm2.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param backbone.norm2.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param backbone.norm3.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param backbone.norm3.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.lateral_convs.0.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.lateral_convs.0.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.lateral_convs.1.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.lateral_convs.1.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.lateral_convs.2.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.lateral_convs.2.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.lateral_convs.3.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.lateral_convs.3.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.fpn_convs.0.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.fpn_convs.0.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.fpn_convs.1.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.fpn_convs.1.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.fpn_convs.2.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.fpn_convs.2.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.fpn_convs.3.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param neck.fpn_convs.3.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param rpn_head.rpn_conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param rpn_head.rpn_conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param rpn_head.rpn_cls.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param rpn_head.rpn_cls.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param rpn_head.rpn_reg.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param rpn_head.rpn_reg.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.fc_cls.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.fc_cls.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.fc_reg.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.fc_reg.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.0.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.0.bn.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.0.bn.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.1.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.1.bn.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.1.bn.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.2.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.2.bn.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.2.bn.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.3.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.3.bn.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.shared_convs.3.bn.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.shared_fcs.0.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.0.shared_fcs.0.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.fc_cls.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.fc_cls.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.fc_reg.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.fc_reg.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.0.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.0.bn.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.0.bn.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.1.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.1.bn.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.1.bn.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.2.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.2.bn.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.2.bn.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.3.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.3.bn.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.shared_convs.3.bn.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.shared_fcs.0.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.1.shared_fcs.0.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.fc_cls.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.fc_cls.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.fc_reg.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.fc_reg.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.0.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.0.bn.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.0.bn.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.1.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.1.bn.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.1.bn.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.2.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.2.bn.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.2.bn.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.3.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.3.bn.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.shared_convs.3.bn.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.shared_fcs.0.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.bbox_head.2.shared_fcs.0.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.0.convs.0.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.0.convs.0.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.0.convs.1.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.0.convs.1.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.0.convs.2.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.0.convs.2.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.0.convs.3.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.0.convs.3.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.0.upsample.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.0.upsample.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.0.conv_logits.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.0.conv_logits.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.1.convs.0.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.1.convs.0.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.1.convs.1.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.1.convs.1.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.1.convs.2.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.1.convs.2.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.1.convs.3.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.1.convs.3.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.1.upsample.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.1.upsample.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.1.conv_logits.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.1.conv_logits.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.2.convs.0.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.2.convs.0.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.2.convs.1.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.2.convs.1.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.2.convs.2.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.2.convs.2.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.2.convs.3.conv.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.2.convs.3.conv.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.2.upsample.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.2.upsample.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.2.conv_logits.weight as id 7
# 07/31 13:18:39 - mmengine - INFO - set param roi_head.mask_head.2.conv_logits.bias as id 7
# 07/31 13:18:39 - mmengine - INFO - Param groups = {
#   "layer_0_decay": {
#     "param_names": [
#       "backbone.downsample_layers.0.0.weight"
#     ],
#     "lr_scale": 0.08235429999999996,
#     "lr": 1.6470859999999992e-07,
#     "weight_decay": 0.05
#   },
#   "layer_0_no_decay": {
#     "param_names": [
#       "backbone.downsample_layers.0.0.bias",
#       "backbone.downsample_layers.0.1.weight",
#       "backbone.downsample_layers.0.1.bias"
#     ],
#     "lr_scale": 0.08235429999999996,
#     "lr": 1.6470859999999992e-07,
#     "weight_decay": 0.0
#   },
#   "layer_2_no_decay": {
#     "param_names": [
#       "backbone.downsample_layers.1.0.weight",
#       "backbone.downsample_layers.1.0.bias",
#       "backbone.downsample_layers.1.1.bias",
#       "backbone.stages.1.0.gamma",
#       "backbone.stages.1.0.depthwise_conv.bias",
#       "backbone.stages.1.0.norm.weight",
#       "backbone.stages.1.0.norm.bias",
#       "backbone.stages.1.0.pointwise_conv1.bias",
#       "backbone.stages.1.0.pointwise_conv2.bias",
#       "backbone.stages.1.1.gamma",
#       "backbone.stages.1.1.depthwise_conv.bias",
#       "backbone.stages.1.1.norm.weight",
#       "backbone.stages.1.1.norm.bias",
#       "backbone.stages.1.1.pointwise_conv1.bias",
#       "backbone.stages.1.1.pointwise_conv2.bias",
#       "backbone.stages.1.2.gamma",
#       "backbone.stages.1.2.depthwise_conv.bias",
#       "backbone.stages.1.2.norm.weight",
#       "backbone.stages.1.2.norm.bias",
#       "backbone.stages.1.2.pointwise_conv1.bias",
#       "backbone.stages.1.2.pointwise_conv2.bias"
#     ],
#     "lr_scale": 0.16806999999999994,
#     "lr": 3.361399999999999e-07,
#     "weight_decay": 0.0
#   },
#   "layer_2_decay": {
#     "param_names": [
#       "backbone.downsample_layers.1.1.weight",
#       "backbone.stages.1.0.depthwise_conv.weight",
#       "backbone.stages.1.0.pointwise_conv1.weight",
#       "backbone.stages.1.0.pointwise_conv2.weight",
#       "backbone.stages.1.1.depthwise_conv.weight",
#       "backbone.stages.1.1.pointwise_conv1.weight",
#       "backbone.stages.1.1.pointwise_conv2.weight",
#       "backbone.stages.1.2.depthwise_conv.weight",
#       "backbone.stages.1.2.pointwise_conv1.weight",
#       "backbone.stages.1.2.pointwise_conv2.weight"
#     ],
#     "lr_scale": 0.16806999999999994,
#     "lr": 3.361399999999999e-07,
#     "weight_decay": 0.05
#   },
#   "layer_3_no_decay": {
#     "param_names": [
#       "backbone.downsample_layers.2.0.weight",
#       "backbone.downsample_layers.2.0.bias",
#       "backbone.downsample_layers.2.1.bias",
#       "backbone.stages.2.0.gamma",
#       "backbone.stages.2.0.depthwise_conv.bias",
#       "backbone.stages.2.0.norm.weight",
#       "backbone.stages.2.0.norm.bias",
#       "backbone.stages.2.0.pointwise_conv1.bias",
#       "backbone.stages.2.0.pointwise_conv2.bias",
#       "backbone.stages.2.1.gamma",
#       "backbone.stages.2.1.depthwise_conv.bias",
#       "backbone.stages.2.1.norm.weight",
#       "backbone.stages.2.1.norm.bias",
#       "backbone.stages.2.1.pointwise_conv1.bias",
#       "backbone.stages.2.1.pointwise_conv2.bias",
#       "backbone.stages.2.2.gamma",
#       "backbone.stages.2.2.depthwise_conv.bias",
#       "backbone.stages.2.2.norm.weight",
#       "backbone.stages.2.2.norm.bias",
#       "backbone.stages.2.2.pointwise_conv1.bias",
#       "backbone.stages.2.2.pointwise_conv2.bias"
#     ],
#     "lr_scale": 0.24009999999999995,
#     "lr": 4.801999999999999e-07,
#     "weight_decay": 0.0
#   },
#   "layer_3_decay": {
#     "param_names": [
#       "backbone.downsample_layers.2.1.weight",
#       "backbone.stages.2.0.depthwise_conv.weight",
#       "backbone.stages.2.0.pointwise_conv1.weight",
#       "backbone.stages.2.0.pointwise_conv2.weight",
#       "backbone.stages.2.1.depthwise_conv.weight",
#       "backbone.stages.2.1.pointwise_conv1.weight",
#       "backbone.stages.2.1.pointwise_conv2.weight",
#       "backbone.stages.2.2.depthwise_conv.weight",
#       "backbone.stages.2.2.pointwise_conv1.weight",
#       "backbone.stages.2.2.pointwise_conv2.weight"
#     ],
#     "lr_scale": 0.24009999999999995,
#     "lr": 4.801999999999999e-07,
#     "weight_decay": 0.05
#   },
#   "layer_6_no_decay": {
#     "param_names": [
#       "backbone.downsample_layers.3.0.weight",
#       "backbone.downsample_layers.3.0.bias",
#       "backbone.downsample_layers.3.1.bias",
#       "backbone.stages.3.0.gamma",
#       "backbone.stages.3.0.depthwise_conv.bias",
#       "backbone.stages.3.0.norm.weight",
#       "backbone.stages.3.0.norm.bias",
#       "backbone.stages.3.0.pointwise_conv1.bias",
#       "backbone.stages.3.0.pointwise_conv2.bias",
#       "backbone.stages.3.1.gamma",
#       "backbone.stages.3.1.depthwise_conv.bias",
#       "backbone.stages.3.1.norm.weight",
#       "backbone.stages.3.1.norm.bias",
#       "backbone.stages.3.1.pointwise_conv1.bias",
#       "backbone.stages.3.1.pointwise_conv2.bias",
#       "backbone.stages.3.2.gamma",
#       "backbone.stages.3.2.depthwise_conv.bias",
#       "backbone.stages.3.2.norm.weight",
#       "backbone.stages.3.2.norm.bias",
#       "backbone.stages.3.2.pointwise_conv1.bias",
#       "backbone.stages.3.2.pointwise_conv2.bias"
#     ],
#     "lr_scale": 0.7,
#     "lr": 1.4e-06,
#     "weight_decay": 0.0
#   },
#   "layer_6_decay": {
#     "param_names": [
#       "backbone.downsample_layers.3.1.weight",
#       "backbone.stages.3.0.depthwise_conv.weight",
#       "backbone.stages.3.0.pointwise_conv1.weight",
#       "backbone.stages.3.0.pointwise_conv2.weight",
#       "backbone.stages.3.1.depthwise_conv.weight",
#       "backbone.stages.3.1.pointwise_conv1.weight",
#       "backbone.stages.3.1.pointwise_conv2.weight",
#       "backbone.stages.3.2.depthwise_conv.weight",
#       "backbone.stages.3.2.pointwise_conv1.weight",
#       "backbone.stages.3.2.pointwise_conv2.weight"
#     ],
#     "lr_scale": 0.7,
#     "lr": 1.4e-06,
#     "weight_decay": 0.05
#   },
#   "layer_1_no_decay": {
#     "param_names": [
#       "backbone.stages.0.0.gamma",
#       "backbone.stages.0.0.depthwise_conv.bias",
#       "backbone.stages.0.0.norm.weight",
#       "backbone.stages.0.0.norm.bias",
#       "backbone.stages.0.0.pointwise_conv1.bias",
#       "backbone.stages.0.0.pointwise_conv2.bias",
#       "backbone.stages.0.1.gamma",
#       "backbone.stages.0.1.depthwise_conv.bias",
#       "backbone.stages.0.1.norm.weight",
#       "backbone.stages.0.1.norm.bias",
#       "backbone.stages.0.1.pointwise_conv1.bias",
#       "backbone.stages.0.1.pointwise_conv2.bias",
#       "backbone.stages.0.2.gamma",
#       "backbone.stages.0.2.depthwise_conv.bias",
#       "backbone.stages.0.2.norm.weight",
#       "backbone.stages.0.2.norm.bias",
#       "backbone.stages.0.2.pointwise_conv1.bias",
#       "backbone.stages.0.2.pointwise_conv2.bias"
#     ],
#     "lr_scale": 0.11764899999999996,
#     "lr": 2.3529799999999991e-07,
#     "weight_decay": 0.0
#   },
#   "layer_1_decay": {
#     "param_names": [
#       "backbone.stages.0.0.depthwise_conv.weight",
#       "backbone.stages.0.0.pointwise_conv1.weight",
#       "backbone.stages.0.0.pointwise_conv2.weight",
#       "backbone.stages.0.1.depthwise_conv.weight",
#       "backbone.stages.0.1.pointwise_conv1.weight",
#       "backbone.stages.0.1.pointwise_conv2.weight",
#       "backbone.stages.0.2.depthwise_conv.weight",
#       "backbone.stages.0.2.pointwise_conv1.weight",
#       "backbone.stages.0.2.pointwise_conv2.weight"
#     ],
#     "lr_scale": 0.11764899999999996,
#     "lr": 2.3529799999999991e-07,
#     "weight_decay": 0.05
#   },
#   "layer_4_no_decay": {
#     "param_names": [
#       "backbone.stages.2.3.gamma",
#       "backbone.stages.2.3.depthwise_conv.bias",
#       "backbone.stages.2.3.norm.weight",
#       "backbone.stages.2.3.norm.bias",
#       "backbone.stages.2.3.pointwise_conv1.bias",
#       "backbone.stages.2.3.pointwise_conv2.bias",
#       "backbone.stages.2.4.gamma",
#       "backbone.stages.2.4.depthwise_conv.bias",
#       "backbone.stages.2.4.norm.weight",
#       "backbone.stages.2.4.norm.bias",
#       "backbone.stages.2.4.pointwise_conv1.bias",
#       "backbone.stages.2.4.pointwise_conv2.bias",
#       "backbone.stages.2.5.gamma",
#       "backbone.stages.2.5.depthwise_conv.bias",
#       "backbone.stages.2.5.norm.weight",
#       "backbone.stages.2.5.norm.bias",
#       "backbone.stages.2.5.pointwise_conv1.bias",
#       "backbone.stages.2.5.pointwise_conv2.bias"
#     ],
#     "lr_scale": 0.3429999999999999,
#     "lr": 6.859999999999998e-07,
#     "weight_decay": 0.0
#   },
#   "layer_4_decay": {
#     "param_names": [
#       "backbone.stages.2.3.depthwise_conv.weight",
#       "backbone.stages.2.3.pointwise_conv1.weight",
#       "backbone.stages.2.3.pointwise_conv2.weight",
#       "backbone.stages.2.4.depthwise_conv.weight",
#       "backbone.stages.2.4.pointwise_conv1.weight",
#       "backbone.stages.2.4.pointwise_conv2.weight",
#       "backbone.stages.2.5.depthwise_conv.weight",
#       "backbone.stages.2.5.pointwise_conv1.weight",
#       "backbone.stages.2.5.pointwise_conv2.weight"
#     ],
#     "lr_scale": 0.3429999999999999,
#     "lr": 6.859999999999998e-07,
#     "weight_decay": 0.05
#   },
#   "layer_5_no_decay": {
#     "param_names": [
#       "backbone.stages.2.6.gamma",
#       "backbone.stages.2.6.depthwise_conv.bias",
#       "backbone.stages.2.6.norm.weight",
#       "backbone.stages.2.6.norm.bias",
#       "backbone.stages.2.6.pointwise_conv1.bias",
#       "backbone.stages.2.6.pointwise_conv2.bias",
#       "backbone.stages.2.7.gamma",
#       "backbone.stages.2.7.depthwise_conv.bias",
#       "backbone.stages.2.7.norm.weight",
#       "backbone.stages.2.7.norm.bias",
#       "backbone.stages.2.7.pointwise_conv1.bias",
#       "backbone.stages.2.7.pointwise_conv2.bias",
#       "backbone.stages.2.8.gamma",
#       "backbone.stages.2.8.depthwise_conv.bias",
#       "backbone.stages.2.8.norm.weight",
#       "backbone.stages.2.8.norm.bias",
#       "backbone.stages.2.8.pointwise_conv1.bias",
#       "backbone.stages.2.8.pointwise_conv2.bias"
#     ],
#     "lr_scale": 0.48999999999999994,
#     "lr": 9.799999999999997e-07,
#     "weight_decay": 0.0
#   },
#   "layer_5_decay": {
#     "param_names": [
#       "backbone.stages.2.6.depthwise_conv.weight",
#       "backbone.stages.2.6.pointwise_conv1.weight",
#       "backbone.stages.2.6.pointwise_conv2.weight",
#       "backbone.stages.2.7.depthwise_conv.weight",
#       "backbone.stages.2.7.pointwise_conv1.weight",
#       "backbone.stages.2.7.pointwise_conv2.weight",
#       "backbone.stages.2.8.depthwise_conv.weight",
#       "backbone.stages.2.8.pointwise_conv1.weight",
#       "backbone.stages.2.8.pointwise_conv2.weight"
#     ],
#     "lr_scale": 0.48999999999999994,
#     "lr": 9.799999999999997e-07,
#     "weight_decay": 0.05
#   },
#   "layer_7_no_decay": {
#     "param_names": [
#       "backbone.norm0.weight",
#       "backbone.norm0.bias",
#       "backbone.norm1.weight",
#       "backbone.norm1.bias",
#       "backbone.norm2.weight",
#       "backbone.norm2.bias",
#       "backbone.norm3.weight",
#       "backbone.norm3.bias",
#       "neck.lateral_convs.0.conv.bias",
#       "neck.lateral_convs.1.conv.bias",
#       "neck.lateral_convs.2.conv.bias",
#       "neck.lateral_convs.3.conv.bias",
#       "neck.fpn_convs.0.conv.bias",
#       "neck.fpn_convs.1.conv.bias",
#       "neck.fpn_convs.2.conv.bias",
#       "neck.fpn_convs.3.conv.bias",
#       "rpn_head.rpn_conv.bias",
#       "rpn_head.rpn_cls.bias",
#       "rpn_head.rpn_reg.bias",
#       "roi_head.bbox_head.0.fc_cls.bias",
#       "roi_head.bbox_head.0.fc_reg.bias",
#       "roi_head.bbox_head.0.shared_convs.0.bn.weight",
#       "roi_head.bbox_head.0.shared_convs.0.bn.bias",
#       "roi_head.bbox_head.0.shared_convs.1.bn.weight",
#       "roi_head.bbox_head.0.shared_convs.1.bn.bias",
#       "roi_head.bbox_head.0.shared_convs.2.bn.weight",
#       "roi_head.bbox_head.0.shared_convs.2.bn.bias",
#       "roi_head.bbox_head.0.shared_convs.3.bn.weight",
#       "roi_head.bbox_head.0.shared_convs.3.bn.bias",
#       "roi_head.bbox_head.0.shared_fcs.0.bias",
#       "roi_head.bbox_head.1.fc_cls.bias",
#       "roi_head.bbox_head.1.fc_reg.bias",
#       "roi_head.bbox_head.1.shared_convs.0.bn.weight",
#       "roi_head.bbox_head.1.shared_convs.0.bn.bias",
#       "roi_head.bbox_head.1.shared_convs.1.bn.weight",
#       "roi_head.bbox_head.1.shared_convs.1.bn.bias",
#       "roi_head.bbox_head.1.shared_convs.2.bn.weight",
#       "roi_head.bbox_head.1.shared_convs.2.bn.bias",
#       "roi_head.bbox_head.1.shared_convs.3.bn.weight",
#       "roi_head.bbox_head.1.shared_convs.3.bn.bias",
#       "roi_head.bbox_head.1.shared_fcs.0.bias",
#       "roi_head.bbox_head.2.fc_cls.bias",
#       "roi_head.bbox_head.2.fc_reg.bias",
#       "roi_head.bbox_head.2.shared_convs.0.bn.weight",
#       "roi_head.bbox_head.2.shared_convs.0.bn.bias",
#       "roi_head.bbox_head.2.shared_convs.1.bn.weight",
#       "roi_head.bbox_head.2.shared_convs.1.bn.bias",
#       "roi_head.bbox_head.2.shared_convs.2.bn.weight",
#       "roi_head.bbox_head.2.shared_convs.2.bn.bias",
#       "roi_head.bbox_head.2.shared_convs.3.bn.weight",
#       "roi_head.bbox_head.2.shared_convs.3.bn.bias",
#       "roi_head.bbox_head.2.shared_fcs.0.bias",
#       "roi_head.mask_head.0.convs.0.conv.bias",
#       "roi_head.mask_head.0.convs.1.conv.bias",
#       "roi_head.mask_head.0.convs.2.conv.bias",
#       "roi_head.mask_head.0.convs.3.conv.bias",
#       "roi_head.mask_head.0.upsample.bias",
#       "roi_head.mask_head.0.conv_logits.bias",
#       "roi_head.mask_head.1.convs.0.conv.bias",
#       "roi_head.mask_head.1.convs.1.conv.bias",
#       "roi_head.mask_head.1.convs.2.conv.bias",
#       "roi_head.mask_head.1.convs.3.conv.bias",
#       "roi_head.mask_head.1.upsample.bias",
#       "roi_head.mask_head.1.conv_logits.bias",
#       "roi_head.mask_head.2.convs.0.conv.bias",
#       "roi_head.mask_head.2.convs.1.conv.bias",
#       "roi_head.mask_head.2.convs.2.conv.bias",
#       "roi_head.mask_head.2.convs.3.conv.bias",
#       "roi_head.mask_head.2.upsample.bias",
#       "roi_head.mask_head.2.conv_logits.bias"
#     ],
#     "lr_scale": 1.0,
#     "lr": 2e-06,
#     "weight_decay": 0.0
#   },
#   "layer_7_decay": {
#     "param_names": [
#       "neck.lateral_convs.0.conv.weight",
#       "neck.lateral_convs.1.conv.weight",
#       "neck.lateral_convs.2.conv.weight",
#       "neck.lateral_convs.3.conv.weight",
#       "neck.fpn_convs.0.conv.weight",
#       "neck.fpn_convs.1.conv.weight",
#       "neck.fpn_convs.2.conv.weight",
#       "neck.fpn_convs.3.conv.weight",
#       "rpn_head.rpn_conv.weight",
#       "rpn_head.rpn_cls.weight",
#       "rpn_head.rpn_reg.weight",
#       "roi_head.bbox_head.0.fc_cls.weight",
#       "roi_head.bbox_head.0.fc_reg.weight",
#       "roi_head.bbox_head.0.shared_convs.0.conv.weight",
#       "roi_head.bbox_head.0.shared_convs.1.conv.weight",
#       "roi_head.bbox_head.0.shared_convs.2.conv.weight",
#       "roi_head.bbox_head.0.shared_convs.3.conv.weight",
#       "roi_head.bbox_head.0.shared_fcs.0.weight",
#       "roi_head.bbox_head.1.fc_cls.weight",
#       "roi_head.bbox_head.1.fc_reg.weight",
#       "roi_head.bbox_head.1.shared_convs.0.conv.weight",
#       "roi_head.bbox_head.1.shared_convs.1.conv.weight",
#       "roi_head.bbox_head.1.shared_convs.2.conv.weight",
#       "roi_head.bbox_head.1.shared_convs.3.conv.weight",
#       "roi_head.bbox_head.1.shared_fcs.0.weight",
#       "roi_head.bbox_head.2.fc_cls.weight",
#       "roi_head.bbox_head.2.fc_reg.weight",
#       "roi_head.bbox_head.2.shared_convs.0.conv.weight",
#       "roi_head.bbox_head.2.shared_convs.1.conv.weight",
#       "roi_head.bbox_head.2.shared_convs.2.conv.weight",
#       "roi_head.bbox_head.2.shared_convs.3.conv.weight",
#       "roi_head.bbox_head.2.shared_fcs.0.weight",
#       "roi_head.mask_head.0.convs.0.conv.weight",
#       "roi_head.mask_head.0.convs.1.conv.weight",
#       "roi_head.mask_head.0.convs.2.conv.weight",
#       "roi_head.mask_head.0.convs.3.conv.weight",
#       "roi_head.mask_head.0.upsample.weight",
#       "roi_head.mask_head.0.conv_logits.weight",
#       "roi_head.mask_head.1.convs.0.conv.weight",
#       "roi_head.mask_head.1.convs.1.conv.weight",
#       "roi_head.mask_head.1.convs.2.conv.weight",
#       "roi_head.mask_head.1.convs.3.conv.weight",
#       "roi_head.mask_head.1.upsample.weight",
#       "roi_head.mask_head.1.conv_logits.weight",
#       "roi_head.mask_head.2.convs.0.conv.weight",
#       "roi_head.mask_head.2.convs.1.conv.weight",
#       "roi_head.mask_head.2.convs.2.conv.weight",
#       "roi_head.mask_head.2.convs.3.conv.weight",
#       "roi_head.mask_head.2.upsample.weight",
#       "roi_head.mask_head.2.conv_logits.weight"
#     ],
#     "lr_scale": 1.0,
#     "lr": 2e-06,
#     "weight_decay": 0.05
#   }
# }
# loading annotations into memory...
# Done (t=0.04s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# 07/31 13:18:40 - mmengine - INFO - load backbone. in model from: https://download.openmmlab.com/mmclassification/v0/convnext/downstream/convnext-tiny_3rdparty_32xb128-noema_in1k_20220301-795e9634.pth
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmclassification/v0/convnext/downstream/convnext-tiny_3rdparty_32xb128-noema_in1k_20220301-795e9634.pth
# Downloading: "https://download.openmmlab.com/mmclassification/v0/convnext/downstream/convnext-tiny_3rdparty_32xb128-noema_in1k_20220301-795e9634.pth" to /root/.cache/torch/hub/checkpoints/convnext-tiny_3rdparty_32xb128-noema_in1k_20220301-795e9634.pth
# 07/31 13:20:03 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# missing keys in source state_dict: norm0.weight, norm0.bias, norm1.weight, norm1.bias, norm2.weight, norm2.bias, norm3.weight, norm3.bias
#
# Loads checkpoint by local backend from path: /notebooks/data/output/pseudo_fold/exp101_convnext_validchange_pseudo05_ens/epoch_1.pth
# 07/31 13:20:08 - mmengine - INFO - Load checkpoint from /notebooks/data/output/pseudo_fold/exp101_convnext_validchange_pseudo05_ens/epoch_1.pth
# 07/31 13:20:08 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 07/31 13:20:08 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 07/31 13:20:08 - mmengine - INFO - Checkpoints will be saved to /notebooks/data/output/convnext_fold_pseudo2_095_lr-6_10000.
# 07/31 13:21:10 - mmengine - INFO - Iter(train) [  100/10000]  base_lr: 2.0000e-07 lr: 1.6471e-08  eta: 1:42:41  time: 0.5963  data_time: 0.0958  memory: 10539  loss: 1.3438  loss_rpn_cls: 0.0248  loss_rpn_bbox: 0.0222  s0.loss_cls: 0.1980  s0.acc: 91.3086  s0.loss_bbox: 0.3331  s0.loss_mask: 0.1852  s1.loss_cls: 0.1180  s1.acc: 90.1309  s1.loss_bbox: 0.1730  s1.loss_mask: 0.0977  s2.loss_cls: 0.0668  s2.acc: 89.9898  s2.loss_bbox: 0.0786  s2.loss_mask: 0.0465
# 07/31 13:22:08 - mmengine - INFO - Iter(train) [  200/10000]  base_lr: 4.0000e-07 lr: 3.2942e-08  eta: 1:38:40  time: 0.6276  data_time: 0.0938  memory: 10536  loss: 1.4281  loss_rpn_cls: 0.0216  loss_rpn_bbox: 0.0311  s0.loss_cls: 0.2043  s0.acc: 95.4102  s0.loss_bbox: 0.3446  s0.loss_mask: 0.2373  s1.loss_cls: 0.1235  s1.acc: 97.0499  s1.loss_bbox: 0.1658  s1.loss_mask: 0.1127  s2.loss_cls: 0.0713  s2.acc: 96.2051  s2.loss_bbox: 0.0657  s2.loss_mask: 0.0502
# 07/31 13:23:04 - mmengine - INFO - Iter(train) [  300/10000]  base_lr: 6.0000e-07 lr: 4.9413e-08  eta: 1:35:13  time: 0.4724  data_time: 0.0596  memory: 10535  loss: 1.1033  loss_rpn_cls: 0.0136  loss_rpn_bbox: 0.0170  s0.loss_cls: 0.1594  s0.acc: 91.6016  s0.loss_bbox: 0.2691  s0.loss_mask: 0.1703  s1.loss_cls: 0.0924  s1.acc: 91.0872  s1.loss_bbox: 0.1394  s1.loss_mask: 0.0894  s2.loss_cls: 0.0508  s2.acc: 90.0000  s2.loss_bbox: 0.0600  s2.loss_mask: 0.0419
# 07/31 13:24:00 - mmengine - INFO - Iter(train) [  400/10000]  base_lr: 8.0000e-07 lr: 6.5883e-08  eta: 1:32:55  time: 0.5478  data_time: 0.0978  memory: 10538  loss: 1.2320  loss_rpn_cls: 0.0276  loss_rpn_bbox: 0.0198  s0.loss_cls: 0.1855  s0.acc: 95.1172  s0.loss_bbox: 0.2991  s0.loss_mask: 0.1721  s1.loss_cls: 0.1126  s1.acc: 94.7525  s1.loss_bbox: 0.1523  s1.loss_mask: 0.0892  s2.loss_cls: 0.0646  s2.acc: 91.3947  s2.loss_bbox: 0.0664  s2.loss_mask: 0.0428
# 07/31 13:24:59 - mmengine - INFO - Iter(train) [  500/10000]  base_lr: 1.0000e-06 lr: 8.2354e-08  eta: 1:32:08  time: 0.5476  data_time: 0.0595  memory: 10540  loss: 1.1147  loss_rpn_cls: 0.0213  loss_rpn_bbox: 0.0174  s0.loss_cls: 0.1591  s0.acc: 93.6523  s0.loss_bbox: 0.2854  s0.loss_mask: 0.1545  s1.loss_cls: 0.0912  s1.acc: 92.3828  s1.loss_bbox: 0.1488  s1.loss_mask: 0.0825  s2.loss_cls: 0.0514  s2.acc: 90.0391  s2.loss_bbox: 0.0640  s2.loss_mask: 0.0391
# 07/31 13:25:08 - mmengine - INFO - Iter(val) [100/270]    eta: 0:00:15  time: 0.0972  data_time: 0.0107  memory: 1695
# 07/31 13:25:17 - mmengine - INFO - Iter(val) [200/270]    eta: 0:00:06  time: 0.0941  data_time: 0.0110  memory: 1695
# 07/31 13:25:24 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.38s).
# ...
# 07/31 14:24:27 - mmengine - INFO - Iter(train) [ 6300/10000]  base_lr: 7.2470e-07 lr: 5.9682e-08  eta: 0:34:38  time: 0.5958  data_time: 0.0890  memory: 10538  loss: 0.7785  loss_rpn_cls: 0.0064  loss_rpn_bbox: 0.0118  s0.loss_cls: 0.1024  s0.acc: 95.3125  s0.loss_bbox: 0.2006  s0.loss_mask: 0.1246  s1.loss_cls: 0.0521  s1.acc: 94.2799  s1.loss_bbox: 0.1013  s1.loss_mask: 0.0696  s2.loss_cls: 0.0288  s2.acc: 92.1162  s2.loss_bbox: 0.0473  s2.loss_mask: 0.0336
# 07/31 14:25:24 - mmengine - INFO - Iter(train) [ 6400/10000]  base_lr: 6.9132e-07 lr: 5.6933e-08  eta: 0:33:42  time: 0.5367  data_time: 0.0795  memory: 10537  loss: 0.8740  loss_rpn_cls: 0.0147  loss_rpn_bbox: 0.0151  s0.loss_cls: 0.1414  s0.acc: 96.5820  s0.loss_bbox: 0.2068  s0.loss_mask: 0.1254  s1.loss_cls: 0.0726  s1.acc: 96.2891  s1.loss_bbox: 0.1045  s1.loss_mask: 0.0708  s2.loss_cls: 0.0405  s2.acc: 95.8984  s2.loss_bbox: 0.0472  s2.loss_mask: 0.0350
# 07/31 14:26:20 - mmengine - INFO - Iter(train) [ 6500/10000]  base_lr: 6.5831e-07 lr: 5.4214e-08  eta: 0:32:46  time: 0.5699  data_time: 0.0763  memory: 10536  loss: 0.8101  loss_rpn_cls: 0.0093  loss_rpn_bbox: 0.0113  s0.loss_cls: 0.1049  s0.acc: 96.2891  s0.loss_bbox: 0.2175  s0.loss_mask: 0.1160  s1.loss_cls: 0.0557  s1.acc: 96.8597  s1.loss_bbox: 0.1114  s1.loss_mask: 0.0679  s2.loss_cls: 0.0306  s2.acc: 96.2709  s2.loss_bbox: 0.0519  s2.loss_mask: 0.0337
# 07/31 14:26:31 - mmengine - INFO - Iter(val) [100/270]    eta: 0:00:17  time: 0.0998  data_time: 0.0117  memory: 1695
# 07/31 14:26:41 - mmengine - INFO - Iter(val) [200/270]    eta: 0:00:07  time: 0.0998  data_time: 0.0105  memory: 1695
# 07/31 14:26:48 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.46s).
# Accumulating evaluation results...
# DONE (t=0.09s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.333
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.612
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.339
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.393
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.419
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.375
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.568
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.523
# 07/31 14:26:48 - mmengine - INFO - segm_mAP_copypaste: 0.333 0.612 0.339 0.107 0.393 0.419
# 07/31 14:26:48 - mmengine - INFO - Iter(val) [270/270]    coco/segm_mAP: 0.3330  coco/segm_mAP_50: 0.6120  coco/segm_mAP_75: 0.3390  coco/segm_mAP_s: 0.1070  coco/segm_mAP_m: 0.3930  coco/segm_mAP_l: 0.4190  data_time: 0.0107  time: 0.0999
# 07/31 14:27:44 - mmengine - INFO - Iter(train) [ 6600/10000]  base_lr: 6.2572e-07 lr: 5.1530e-08  eta: 0:31:50  time: 0.5009  data_time: 0.0531  memory: 10537  loss: 0.7508  loss_rpn_cls: 0.0069  loss_rpn_bbox: 0.0112  s0.loss_cls: 0.0989  s0.acc: 96.9727  s0.loss_bbox: 0.1811  s0.loss_mask: 0.1261  s1.loss_cls: 0.0498  s1.acc: 96.8222  s1.loss_bbox: 0.0954  s1.loss_mask: 0.0728  s2.loss_cls: 0.0289  s2.acc: 96.7033  s2.loss_bbox: 0.0447  s2.loss_mask: 0.0352
# 07/31 14:28:39 - mmengine - INFO - Iter(train) [ 6700/10000]  base_lr: 5.9358e-07 lr: 4.8884e-08  eta: 0:30:53  time: 0.6102  data_time: 0.1040  memory: 10543  loss: 0.8206  loss_rpn_cls: 0.0093  loss_rpn_bbox: 0.0143  s0.loss_cls: 0.1147  s0.acc: 94.8242  s0.loss_bbox: 0.2195  s0.loss_mask: 0.1132  s1.loss_cls: 0.0647  s1.acc: 94.1896  s1.loss_bbox: 0.1060  s1.loss_mask: 0.0637  s2.loss_cls: 0.0365  s2.acc: 92.0863  s2.loss_bbox: 0.0477  s2.loss_mask: 0.0311
# 07/31 14:29:34 - mmengine - INFO - Iter(train) [ 6800/10000]  base_lr: 5.6194e-07 lr: 4.6278e-08  eta: 0:29:57  time: 0.5064  data_time: 0.0657  memory: 10532  loss: 0.8488  loss_rpn_cls: 0.0155  loss_rpn_bbox: 0.0126  s0.loss_cls: 0.1240  s0.acc: 93.4570  s0.loss_bbox: 0.2115  s0.loss_mask: 0.1184  s1.loss_cls: 0.0705  s1.acc: 92.7146  s1.loss_bbox: 0.1064  s1.loss_mask: 0.0678  s2.loss_cls: 0.0397  s2.acc: 92.9000  s2.loss_bbox: 0.0488  s2.loss_mask: 0.0337
# 07/31 14:30:33 - mmengine - INFO - Iter(train) [ 6900/10000]  base_lr: 5.3084e-07 lr: 4.3717e-08  eta: 0:29:01  time: 0.5300  data_time: 0.0522  memory: 10537  loss: 0.8147  loss_rpn_cls: 0.0118  loss_rpn_bbox: 0.0106  s0.loss_cls: 0.1087  s0.acc: 94.4336  s0.loss_bbox: 0.2125  s0.loss_mask: 0.1197  s1.loss_cls: 0.0609  s1.acc: 94.1872  s1.loss_bbox: 0.1071  s1.loss_mask: 0.0665  s2.loss_cls: 0.0348  s2.acc: 94.0711  s2.loss_bbox: 0.0494  s2.loss_mask: 0.0326
# 07/31 14:31:30 - mmengine - INFO - Exp name: cascade-mask-rcnn_convnext-t-p4-w7_fpn_4conv1fc-giou_amp-ms-crop-3x_coco_20230731_131833
# 07/31 14:31:30 - mmengine - INFO - Iter(train) [ 7000/10000]  base_lr: 5.0030e-07 lr: 4.1202e-08  eta: 0:28:06  time: 0.5867  data_time: 0.0956  memory: 10541  loss: 0.8855  loss_rpn_cls: 0.0153  loss_rpn_bbox: 0.0135  s0.loss_cls: 0.1314  s0.acc: 93.6523  s0.loss_bbox: 0.2279  s0.loss_mask: 0.1213  s1.loss_cls: 0.0691  s1.acc: 96.0278  s1.loss_bbox: 0.1090  s1.loss_mask: 0.0705  s2.loss_cls: 0.0407  s2.acc: 95.3327  s2.loss_bbox: 0.0515  s2.loss_mask: 0.0353
# 07/31 14:31:40 - mmengine - INFO - Iter(val) [100/270]    eta: 0:00:16  time: 0.1002  data_time: 0.0111  memory: 1695
# 07/31 14:31:50 - mmengine - INFO - Iter(val) [200/270]    eta: 0:00:06  time: 0.1001  data_time: 0.0111  memory: 1695
# 07/31 14:31:57 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.41s).
# Accumulating evaluation results...
# DONE (t=0.08s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.331
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.610
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.338
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.105
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.391
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.419
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.520
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.370
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.520
# 07/31 14:31:57 - mmengine - INFO - segm_mAP_copypaste: 0.331 0.610 0.338 0.105 0.391 0.419
# 07/31 14:31:57 - mmengine - INFO - Iter(val) [270/270]    coco/segm_mAP: 0.3310  coco/segm_mAP_50: 0.6100  coco/segm_mAP_75: 0.3380  coco/segm_mAP_s: 0.1050  coco/segm_mAP_m: 0.3910  coco/segm_mAP_l: 0.4190  data_time: 0.0106  time: 0.0986
# 07/31 14:32:55 - mmengine - INFO - Iter(train) [ 7100/10000]  base_lr: 4.7038e-07 lr: 3.8738e-08  eta: 0:27:11  time: 0.5203  data_time: 0.0781  memory: 10543  loss: 0.7824  loss_rpn_cls: 0.0112  loss_rpn_bbox: 0.0106  s0.loss_cls: 0.1084  s0.acc: 96.3867  s0.loss_bbox: 0.1931  s0.loss_mask: 0.1178  s1.loss_cls: 0.0613  s1.acc: 97.9980  s1.loss_bbox: 0.0967  s1.loss_mask: 0.0670  s2.loss_cls: 0.0363  s2.acc: 97.3711  s2.loss_bbox: 0.0469  s2.loss_mask: 0.0332
# 07/31 14:33:52 - mmengine - INFO - Iter(train) [ 7200/10000]  base_lr: 4.4110e-07 lr: 3.6326e-08  eta: 0:26:15  time: 0.5868  data_time: 0.0741  memory: 10540  loss: 0.9271  loss_rpn_cls: 0.0210  loss_rpn_bbox: 0.0177  s0.loss_cls: 0.1270  s0.acc: 96.4844  s0.loss_bbox: 0.2380  s0.loss_mask: 0.1327  s1.loss_cls: 0.0684  s1.acc: 96.8750  s1.loss_bbox: 0.1184  s1.loss_mask: 0.0748  s2.loss_cls: 0.0397  s2.acc: 94.8141  s2.loss_bbox: 0.0528  s2.loss_mask: 0.0366
# 07/31 14:34:49 - mmengine - INFO - Iter(train) [ 7300/10000]  base_lr: 4.1250e-07 lr: 3.3971e-08  eta: 0:25:19  time: 0.5981  data_time: 0.0828  memory: 10535  loss: 0.8513  loss_rpn_cls: 0.0115  loss_rpn_bbox: 0.0136  s0.loss_cls: 0.1160  s0.acc: 96.4844  s0.loss_bbox: 0.2195  s0.loss_mask: 0.1278  s1.loss_cls: 0.0634  s1.acc: 95.0195  s1.loss_bbox: 0.1075  s1.loss_mask: 0.0715  s2.loss_cls: 0.0342  s2.acc: 96.1914  s2.loss_bbox: 0.0510  s2.loss_mask: 0.0353
# 07/31 14:35:45 - mmengine - INFO - Iter(train) [ 7400/10000]  base_lr: 3.8461e-07 lr: 3.1675e-08  eta: 0:24:22  time: 0.5376  data_time: 0.0703  memory: 10537  loss: 0.7496  loss_rpn_cls: 0.0122  loss_rpn_bbox: 0.0131  s0.loss_cls: 0.1017  s0.acc: 95.9961  s0.loss_bbox: 0.1914  s0.loss_mask: 0.1115  s1.loss_cls: 0.0553  s1.acc: 93.1864  s1.loss_bbox: 0.0944  s1.loss_mask: 0.0634  s2.loss_cls: 0.0314  s2.acc: 91.1043  s2.loss_bbox: 0.0437  s2.loss_mask: 0.0314
# 07/31 14:36:41 - mmengine - INFO - Iter(train) [ 7500/10000]  base_lr: 3.5748e-07 lr: 2.9440e-08  eta: 0:23:26  time: 0.6900  data_time: 0.1338  memory: 10535  loss: 0.8239  loss_rpn_cls: 0.0102  loss_rpn_bbox: 0.0162  s0.loss_cls: 0.1071  s0.acc: 94.3359  s0.loss_bbox: 0.2237  s0.loss_mask: 0.1184  s1.loss_cls: 0.0563  s1.acc: 94.0524  s1.loss_bbox: 0.1084  s1.loss_mask: 0.0678  s2.loss_cls: 0.0317  s2.acc: 89.6939  s2.loss_bbox: 0.0506  s2.loss_mask: 0.0334
# 07/31 14:36:51 - mmengine - INFO - Iter(val) [100/270]    eta: 0:00:16  time: 0.0989  data_time: 0.0104  memory: 1695
# 07/31 14:37:01 - mmengine - INFO - Iter(val) [200/270]    eta: 0:00:06  time: 0.0981  data_time: 0.0116  memory: 1695
# 07/31 14:37:08 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.42s).
# Accumulating evaluation results...
# DONE (t=0.08s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.333
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.611
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.340
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.106
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.393
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.421
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.522
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.522
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.522
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.369
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.568
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.525
# 07/31 14:37:08 - mmengine - INFO - segm_mAP_copypaste: 0.333 0.611 0.340 0.106 0.393 0.421
# 07/31 14:37:08 - mmengine - INFO - Iter(val) [270/270]    coco/segm_mAP: 0.3330  coco/segm_mAP_50: 0.6110  coco/segm_mAP_75: 0.3400  coco/segm_mAP_s: 0.1060  coco/segm_mAP_m: 0.3930  coco/segm_mAP_l: 0.4210  data_time: 0.0105  time: 0.0990
# 07/31 14:38:04 - mmengine - INFO - Iter(train) [ 7600/10000]  base_lr: 3.3113e-07 lr: 2.7270e-08  eta: 0:22:30  time: 0.5260  data_time: 0.0555  memory: 10530  loss: 0.7263  loss_rpn_cls: 0.0077  loss_rpn_bbox: 0.0088  s0.loss_cls: 0.1000  s0.acc: 97.2656  s0.loss_bbox: 0.1719  s0.loss_mask: 0.1162  s1.loss_cls: 0.0599  s1.acc: 96.6797  s1.loss_bbox: 0.0884  s1.loss_mask: 0.0660  s2.loss_cls: 0.0344  s2.acc: 96.4844  s2.loss_bbox: 0.0400  s2.loss_mask: 0.0328
# 07/31 14:39:01 - mmengine - INFO - Iter(train) [ 7700/10000]  base_lr: 3.0559e-07 lr: 2.5167e-08  eta: 0:21:34  time: 0.5854  data_time: 0.0754  memory: 10538  loss: 0.8177  loss_rpn_cls: 0.0132  loss_rpn_bbox: 0.0121  s0.loss_cls: 0.1123  s0.acc: 95.3125  s0.loss_bbox: 0.2107  s0.loss_mask: 0.1185  s1.loss_cls: 0.0546  s1.acc: 94.6939  s1.loss_bbox: 0.1094  s1.loss_mask: 0.0700  s2.loss_cls: 0.0314  s2.acc: 95.4071  s2.loss_bbox: 0.0514  s2.loss_mask: 0.0343
# 07/31 14:39:57 - mmengine - INFO - Iter(train) [ 7800/10000]  base_lr: 2.8090e-07 lr: 2.3134e-08  eta: 0:20:37  time: 0.5793  data_time: 0.0859  memory: 10539  loss: 0.8017  loss_rpn_cls: 0.0094  loss_rpn_bbox: 0.0120  s0.loss_cls: 0.1105  s0.acc: 94.5312  s0.loss_bbox: 0.2074  s0.loss_mask: 0.1182  s1.loss_cls: 0.0592  s1.acc: 93.5157  s1.loss_bbox: 0.1034  s1.loss_mask: 0.0673  s2.loss_cls: 0.0321  s2.acc: 93.1633  s2.loss_bbox: 0.0492  s2.loss_mask: 0.0330
# 07/31 14:40:52 - mmengine - INFO - Iter(train) [ 7900/10000]  base_lr: 2.5709e-07 lr: 2.1172e-08  eta: 0:19:41  time: 0.5706  data_time: 0.0763  memory: 10535  loss: 0.8566  loss_rpn_cls: 0.0108  loss_rpn_bbox: 0.0129  s0.loss_cls: 0.1079  s0.acc: 93.9453  s0.loss_bbox: 0.2338  s0.loss_mask: 0.1213  s1.loss_cls: 0.0572  s1.acc: 92.8079  s1.loss_bbox: 0.1207  s1.loss_mask: 0.0702  s2.loss_cls: 0.0332  s2.acc: 90.8465  s2.loss_bbox: 0.0542  s2.loss_mask: 0.0345
# 07/31 14:41:52 - mmengine - INFO - Exp name: cascade-mask-rcnn_convnext-t-p4-w7_fpn_4conv1fc-giou_amp-ms-crop-3x_coco_20230731_131833
# 07/31 14:41:52 - mmengine - INFO - Iter(train) [ 8000/10000]  base_lr: 2.3418e-07 lr: 1.9286e-08  eta: 0:18:45  time: 0.6479  data_time: 0.1123  memory: 10537  loss: 0.9148  loss_rpn_cls: 0.0214  loss_rpn_bbox: 0.0129  s0.loss_cls: 0.1303  s0.acc: 96.4844  s0.loss_bbox: 0.2383  s0.loss_mask: 0.1278  s1.loss_cls: 0.0682  s1.acc: 96.9849  s1.loss_bbox: 0.1185  s1.loss_mask: 0.0704  s2.loss_cls: 0.0389  s2.acc: 95.3535  s2.loss_bbox: 0.0544  s2.loss_mask: 0.0338
# 07/31 14:42:02 - mmengine - INFO - Iter(val) [100/270]    eta: 0:00:17  time: 0.0992  data_time: 0.0112  memory: 1695
# 07/31 14:42:12 - mmengine - INFO - Iter(val) [200/270]    eta: 0:00:07  time: 0.1024  data_time: 0.0108  memory: 1695
# 07/31 14:42:19 - mmengine - INFO - Evaluating segm...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *segm*
# DONE (t=0.43s).
# Accumulating evaluation results...
# DONE (t=0.08s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.333
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = 0.612
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = 0.340
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.107
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.394
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.416
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=300 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=1000 ] = 0.523
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=1000 ] = 0.375
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=1000 ] = 0.568
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=1000 ] = 0.523
# 07/31 14:42:20 - mmengine - INFO - segm_mAP_copypaste: 0.333 0.612 0.340 0.107 0.394 0.416
# 07/31 14:42:20 - mmengine - INFO - Iter(val) [270/270]    coco/segm_mAP: 0.3330  coco/segm_mAP_50: 0.6120  coco/segm_mAP_75: 0.3400  coco/segm_mAP_s: 0.1070  coco/segm_mAP_m: 0.3940  coco/segm_mAP_l: 0.4160  data_time: 0.0106  time: 0.1002

# %% [markdown]
# # Val

# %%
runs = []
for size in [640, 1024, 1536]:
    print(f"[{size}]")
    cfg.load_from = f"{CFG.general.output_path}/{CFG.general.save_name}/epoch_1.pth"
    #cfg.load_from = f"{CFG.general.output_path}/{CFG.general.save_name}/iter_10000.pth"
    cfg.test_pipeline = [
            dict(type="LoadImageFromFile", backend_args=None),
            dict(type="Resize", scale=(size, size), keep_ratio=True),
            dict(type="LoadAnnotations", with_bbox=True, with_mask=True),
            dict(
                type="PackDetInputs",
                meta_keys=("img_id", "img_path", "ori_shape", "img_shape", "scale_factor"))
        ]
    cfg.val_dataloader.dataset.pipeline = cfg.test_pipeline
    runner = Runner.from_cfg(cfg)
    runs.append(runner)

# %%
for run_, size in zip(runs, [640, 1024, 1536]):
    print(f"[{size}]")
    run_.val()

# %%
img = mmcv.imread(f"{CFG.general.input_path}/train/0006ff2aa7cd.tif", channel_order="rgb")
checkpoint_file = f"{CFG.general.output_path}/{CFG.general.save_name}/epoch_1.pth"
model = init_detector(cfg, checkpoint_file)
new_result = inference_detector(model, img)
print(new_result)

# %%
# get built visualizer
visualizer_now = Visualizer.get_current_instance()
# the dataset_meta is loaded from the checkpoint and
# then pass to the model in init_detector
visualizer_now.dataset_meta = model.dataset_meta
# show the results
visualizer_now.add_datasample(
    "new_result",
    img,
    data_sample=new_result,
    draw_gt=False,
    wait_time=0,
    out_file=None,
    pred_score_thr=0.5
)
visualizer_now.show()
